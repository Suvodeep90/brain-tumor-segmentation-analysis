# %%
from tqdm import tqdm
import os
from os import listdir
import time
from random import randint
from os.path import isfile, join
 
import gc 
import numpy as np
from scipy import stats
import pandas as pd
from scipy.ndimage import binary_dilation, binary_erosion
from scipy.ndimage import generic_filter

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.model_selection import KFold

import nibabel as nib
import pydicom as pdm
import nilearn as nl
import nilearn.plotting as nlplt
import h5py

from skimage import feature
from scipy import ndimage as ndi
from skimage.feature import shape_index
from skimage.draw import disk
from skimage import measure
from skimage import feature
from scipy.ndimage import binary_dilation, binary_erosion


import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.animation as anim
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

import seaborn as sns
import imageio
from skimage.transform import resize
from skimage.util import montage
from scipy.ndimage import gaussian_filter

# from IPython.display import Image as show_gif
# from IPython.display import clear_output
# from IPython.display import YouTubeVideo

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn import MSELoss

import trimesh
from trimesh.curvature import discrete_gaussian_curvature_measure, discrete_mean_curvature_measure, sphere_ball_intersection

from __future__ import print_function
import six

import radiomics
from radiomics import featureextractor
import SimpleITK as sitk

import warnings
warnings.filterwarnings('ignore')

# %%
def preprocess_mask_labels(mask):
    # whole tumour
    mask_WT = mask.copy()
    mask_WT[mask_WT == 1] = 1
    mask_WT[mask_WT == 2] = 1
    mask_WT[mask_WT == 3] = 1
    # include all tumours 

    # NCR / NET - LABEL 1
    mask_TC = mask.copy()
    mask_TC[mask_TC == 1] = 1
    mask_TC[mask_TC == 2] = 0
    mask_TC[mask_TC == 3] = 1
    # exclude 2 / 4 labelled tumour 

    # ET - LABEL 4 
    mask_ET = mask.copy()
    mask_ET[mask_ET == 1] = 0
    mask_ET[mask_ET == 2] = 0
    mask_ET[mask_ET == 3] = 1
    # exclude 2 / 1 labelled tumour 

    mask = np.stack([mask_WT, mask_TC, mask_ET])
    
    return mask 

def read_MRI(dataset, patient_id):
    if dataset == 'Brats2020':
        baseloc = '../../input/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
        pefix = 'BraTS20_Training_' + patient_id + '/' + 'BraTS20_Training_' + patient_id
        suffixs = ['_flair.nii','_t2.nii', '_t1.nii', '_t1ce.nii', '_seg.nii']
    elif dataset == 'Brats2023':
        baseloc = '../input/Brats2023/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/'
        pefix = patient_id + '/' + patient_id
        suffixs = ['-t2f.nii.gz','-t2w.nii.gz', '-t1n.nii.gz', '-t1c.nii.gz', '-seg.nii.gz', '-seg..npz']
        outputloc = '../Results/Result/Vanilla_Unet/' + patient_id

    sample_filename1 = baseloc + pefix + suffixs[0]
    sample_img1_f = nib.load(sample_filename1)
    sample_img1 = np.asarray(sample_img1_f.dataobj)
    sample_img1 = sitk.GetImageFromArray(sample_img1)
    # sample_img1 = np.rot90(sample_img1)

    sample_filename2 = baseloc + pefix + suffixs[1]
    sample_img2_f = nib.load(sample_filename2)
    sample_img2 = np.asarray(sample_img2_f.dataobj)
    # sample_img2  = np.rot90(sample_img2)

    sample_filename3 = baseloc + pefix + suffixs[2]
    sample_img3_f = nib.load(sample_filename3)
    sample_img3 = np.asarray(sample_img3_f.dataobj)
    # sample_img3  = np.rot90(sample_img3)

    sample_filename4 = baseloc + pefix + suffixs[3]
    sample_img4_f = nib.load(sample_filename4)
    sample_img4 = np.asarray(sample_img4_f.dataobj)
    # sample_img4  = np.rot90(sample_img4)

    sample_filename_mask = baseloc + pefix + suffixs[4]
    sample_mask_f = nib.load(sample_filename_mask)
    sample_mask = np.asarray(sample_mask_f.dataobj)
#     sample_mask = sitk.GetImageFromArray(sample_mask)
    
    try:
        output_filename_mask = outputloc + suffixs[4]
        output_mask_f = nib.load(output_filename_mask)
        output_mask = np.asarray(output_mask_f.dataobj)
        
        prob_filename = outputloc + suffixs[5]
        probablity_img = np.load(prob_filename, allow_pickle=True)
        probablity_img = probablity_img['arr_0'][0]
        probablity_img = np.moveaxis(probablity_img, (0, 1, 2, 3), (0, 3, 2, 1))
    except ValueError :
        output_mask  = None
        probability_mask = None
        
    return sample_img1, sample_img2, sample_img3, sample_img4, sample_mask, output_mask, probablity_img

# %%
dataset = 'Brats2023'
data_path = '../input/BraTS2023/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/'
patient_ids = [f for f in listdir(data_path) if not isfile(join(data_path, f))]

# %%
sample_img1, sample_img2, sample_img3, sample_img4, mask, output_mask, probability_mask  = read_MRI(dataset, 
                                                                                                    'BraTS-GLI-00006-000')


radius = 10
struct = np.ones((2*radius+1, 2*radius+1, 2*radius+1))


masks = preprocess_mask_labels(mask)
mask_WT, mask_TC, mask_ET = masks[0], masks[1], masks[2]

dilated_mask = binary_dilation(mask_WT,struct)
eroded_mask = binary_erosion(mask_WT,struct)
boundary_region = dilated_mask ^ eroded_mask
boundary_region = boundary_region.astype('float')

sample_mask = sample_img2.astype('bool').astype('float')
unmask_WT = sample_mask - mask_WT
unmask_WT = sitk.GetImageFromArray(unmask_WT)
mask_WT = sitk.GetImageFromArray(mask_WT)
mask_WT = sitk.GetImageFromArray(boundary_region)

# output = preprocess_mask_labels(output_mask)
# output_WT, output_TC, output_ET = output[0], output[1], output[2]

# %%
settings = {}
settings['distances'] = [5]
# settings['force2D'] = True
settings['label'] = 1

# Instantiate the extractor
extractor = featureextractor.RadiomicsFeatureExtractor(**settings)  # ** 'unpacks' the dictionary in the function call
# extractor.enableImageTypeByName('Wavelet')


print('Extraction parameters:\n\t', extractor.settings)
print('Enabled filters:\n\t', extractor.enabledImagetypes)  # Still the default parameters
print('Enabled features:\n\t', extractor.enabledFeatures)  # Still the default parameters

# extractor = featureextractor.RadiomicsFeatureExtractor()
# Out:
# Extraction parameters:
# 	 {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [5], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# Enabled filters:
# 	 {'Original': {}}
# Enabled features:
# 	 {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}

# %%
result = extractor.execute(sample_img1, mask_WT)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
print('Result type:', type(result))  # result is returned in a Python ordered dictionary)
print('')
print('Calculated features')
for key, value in six.iteritems(result):
    print('\t', key, ':', value)
# Out:
# Result type: <class 'collections.OrderedDict'>
#
# Calculated features
# 	 diagnostics_Versions_PyRadiomics : v3.0.1
# 	 diagnostics_Versions_Numpy : 1.21.5
# 	 diagnostics_Versions_SimpleITK : 2.3.1
# 	 diagnostics_Versions_PyWavelet : 1.3.0
# 	 diagnostics_Versions_Python : 3.9.13
# 	 diagnostics_Configuration_Settings : {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [5], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	 diagnostics_Configuration_EnabledImageTypes : {'Original': {}}
# 	 diagnostics_Image-original_Hash : f1a964d0efd92b1f701681b3ef028cf5183a9693
# 	 diagnostics_Image-original_Dimensionality : 3D
# 	 diagnostics_Image-original_Spacing : (1.0, 1.0, 1.0)
# 	 diagnostics_Image-original_Size : (155, 240, 240)
# 	 diagnostics_Image-original_Mean : 222.13272681451613
# 	 diagnostics_Image-original_Minimum : 0.0
# 	 diagnostics_Image-original_Maximum : 4050.0
# 	 diagnostics_Mask-original_Hash : efdd43b17665e6f3098763188145c7de0c1507cc
# 	 diagnostics_Mask-original_Spacing : (1.0, 1.0, 1.0)
# 	 diagnostics_Mask-original_Size : (155, 240, 240)
# 	 diagnostics_Mask-original_BoundingBox : (34, 28, 81, 88, 91, 95)
# 	 diagnostics_Mask-original_VoxelNum : 449500
# 	 diagnostics_Mask-original_VolumeNum : 1
# 	 diagnostics_Mask-original_CenterOfMassIndex : (74.36432258064517, 74.93515239154617, 128.30991768631813)
# 	 diagnostics_Mask-original_CenterOfMass : (74.36432258064517, 74.93515239154617, 128.30991768631813)
# 	 original_shape_Elongation : 0.9156327728329408
# 	 original_shape_Flatness : 0.8825576124282378
# 	 original_shape_LeastAxisLength : 82.9967856190601
# 	 original_shape_MajorAxisLength : 94.0412098318496
# 	 original_shape_Maximum2DDiameterColumn : 102.9417310909429
# 	 original_shape_Maximum2DDiameterRow : 108.30050784737807
# 	 original_shape_Maximum2DDiameterSlice : 104.48444860360799
# 	 original_shape_Maximum3DDiameter : 114.69088891450794
# 	 original_shape_MeshVolume : 449423.9583333333
# 	 original_shape_MinorAxisLength : 86.10721371890087
# 	 original_shape_Sphericity : 0.7590428921374155
# 	 original_shape_SurfaceArea : 37381.37629410715
# 	 original_shape_SurfaceVolumeRatio : 0.08317619833338247
# 	 original_shape_VoxelVolume : 449500.0
# 	 original_firstorder_10Percentile : 0.0
# 	 original_firstorder_90Percentile : 2965.0
# 	 original_firstorder_Energy : 1292859349514.0
# 	 original_firstorder_Entropy : 5.812663547625503
# 	 original_firstorder_InterquartileRange : 2116.0
# 	 original_firstorder_Kurtosis : 1.997617939448581
# 	 original_firstorder_Maximum : 4050.0
# 	 original_firstorder_MeanAbsoluteDeviation : 903.3157469859502
# 	 original_firstorder_Mean : 1298.961895439377
# 	 original_firstorder_Median : 1231.0
# 	 original_firstorder_Minimum : 0.0
# 	 original_firstorder_Range : 4050.0
# 	 original_firstorder_RobustMeanAbsoluteDeviation : 773.3940726054785
# 	 original_firstorder_RootMeanSquared : 1695.9412056111726
# 	 original_firstorder_Skewness : 0.36020130154557134
# 	 original_firstorder_TotalEnergy : 1292859349514.0
# 	 original_firstorder_Uniformity : 0.08358807837159322
# 	 original_firstorder_Variance : 1188914.5670864182
# 	 original_glcm_Autocorrelation : 4619.102456953923
# 	 original_glcm_ClusterProminence : 93427730.53712197
# 	 original_glcm_ClusterShade : 141636.66571847865
# 	 original_glcm_ClusterTendency : 6817.970313519339
# 	 original_glcm_Contrast : 772.3784252334349
# 	 original_glcm_Correlation : 0.7963865962739889
# 	 original_glcm_DifferenceAverage : 16.53406828565094
# 	 original_glcm_DifferenceEntropy : 5.240246649077632
# 	 original_glcm_DifferenceVariance : 493.6736223862305
# 	 original_glcm_Id : 0.3217895455648782
# 	 original_glcm_Idm : 0.270486845375496
# 	 original_glcm_Idmn : 0.9757755694116789
# 	 original_glcm_Idn : 0.9193816297235716
# 	 original_glcm_Imc1 : -0.16168534854601588
# 	 original_glcm_Imc2 : 0.9217477602805098
# 	 original_glcm_InverseVariance : 0.06518575152208188
# 	 original_glcm_JointAverage : 55.74304431997784
# 	 original_glcm_JointEnergy : 0.04354587967870367
# 	 original_glcm_JointEntropy : 11.005066209263466
# 	 original_glcm_MCC : 0.8139880193261937
# 	 original_glcm_MaximumProbability : 0.20768780215886604
# 	 original_glcm_SumAverage : 111.48608863995561
# 	 original_glcm_SumEntropy : 7.011068624825097
# 	 original_glcm_SumSquares : 1897.5871846881955
# 	 original_gldm_DependenceEntropy : 11.921953740203294
# 	 original_gldm_DependenceNonUniformity : 6728.689299221357
# 	 original_gldm_DependenceNonUniformityNormalized : 0.014969275415397902
# 	 original_gldm_DependenceVariance : 32049.848574411564
# 	 original_gldm_GrayLevelNonUniformity : 37572.841228031146
# 	 original_gldm_GrayLevelVariance : 1888.3814346388535
# 	 original_gldm_HighGrayLevelEmphasis : 4656.503468298109
# 	 original_gldm_LargeDependenceEmphasis : 47065.883817575086
# 	 original_gldm_LargeDependenceHighGrayLevelEmphasis : 1846395.3134215795
# 	 original_gldm_LargeDependenceLowGrayLevelEmphasis : 46713.28866825346
# 	 original_gldm_LowGrayLevelEmphasis : 0.2804803650185864
# 	 original_gldm_SmallDependenceEmphasis : 0.03091198024685343
# 	 original_gldm_SmallDependenceHighGrayLevelEmphasis : 143.59575967694028
# 	 original_gldm_SmallDependenceLowGrayLevelEmphasis : 6.367686230530669e-05
# 	 original_glrlm_GrayLevelNonUniformity : 3161.513099909064
# 	 original_glrlm_GrayLevelNonUniformityNormalized : 0.010338634653586124
# 	 original_glrlm_GrayLevelVariance : 1308.051603373261
# 	 original_glrlm_HighGrayLevelRunEmphasis : 6267.808432838259
# 	 original_glrlm_LongRunEmphasis : 9.676223524405682
# 	 original_glrlm_LongRunHighGrayLevelEmphasis : 8246.56696352037
# 	 original_glrlm_LongRunLowGrayLevelEmphasis : 8.392489863905336
# 	 original_glrlm_LowGrayLevelRunEmphasis : 0.034517513215595555
# 	 original_glrlm_RunEntropy : 7.479811864200891
# 	 original_glrlm_RunLengthNonUniformity : 242387.97366162002
# 	 original_glrlm_RunLengthNonUniformityNormalized : 0.7930520357584953
# 	 original_glrlm_RunPercentage : 0.6796375459912724
# 	 original_glrlm_RunVariance : 7.506189668851194
# 	 original_glrlm_ShortRunEmphasis : 0.9067449867930039
# 	 original_glrlm_ShortRunHighGrayLevelEmphasis : 5878.45530216197
# 	 original_glrlm_ShortRunLowGrayLevelEmphasis : 0.0027563447900893026
# 	 original_glszm_GrayLevelNonUniformity : 963.4890181223212
# 	 original_glszm_GrayLevelNonUniformityNormalized : 0.00856754537802843
# 	 original_glszm_GrayLevelVariance : 1129.4782698824472
# 	 original_glszm_HighGrayLevelZoneEmphasis : 6295.338268509132
# 	 original_glszm_LargeAreaEmphasis : 141225.67157516585
# 	 original_glszm_LargeAreaHighGrayLevelEmphasis : 1610960.7955058778
# 	 original_glszm_LargeAreaLowGrayLevelEmphasis : 140890.67479901566
# 	 original_glszm_LowGrayLevelZoneEmphasis : 0.0007685166673852467
# 	 original_glszm_SizeZoneNonUniformity : 48899.437087623824
# 	 original_glszm_SizeZoneNonUniformityNormalized : 0.4348239972934235
# 	 original_glszm_SmallAreaEmphasis : 0.6857180037192362
# 	 original_glszm_SmallAreaHighGrayLevelEmphasis : 4226.07027888921
# 	 original_glszm_SmallAreaLowGrayLevelEmphasis : 0.0005326793397373601
# 	 original_glszm_ZoneEntropy : 8.929110707879637
# 	 original_glszm_ZonePercentage : 0.25018464961067854
# 	 original_glszm_ZoneVariance : 141209.69518415644
# 	 original_ngtdm_Busyness : 41.46857933315599
# 	 original_ngtdm_Coarseness : 3.3760019480000777e-06
# 	 original_ngtdm_Complexity : 136981.52287138588
# 	 original_ngtdm_Contrast : 1.4547785833074534
# 	 original_ngtdm_Strength : 0.3540895465024631

# %%
print('Result type:', type(result))  # result is returned in a Python ordered dictionary)
print('')
print('Calculated features')
for key, value in six.iteritems(result):
    print('\t', key, ':', value)
# Out:
# Result type: <class 'collections.OrderedDict'>
#
# Calculated features
# 	 diagnostics_Versions_PyRadiomics : v3.0.1
# 	 diagnostics_Versions_Numpy : 1.21.5
# 	 diagnostics_Versions_SimpleITK : 2.3.1
# 	 diagnostics_Versions_PyWavelet : 1.3.0
# 	 diagnostics_Versions_Python : 3.9.13
# 	 diagnostics_Configuration_Settings : {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	 diagnostics_Configuration_EnabledImageTypes : {'Original': {}}
# 	 diagnostics_Image-original_Hash : f1a964d0efd92b1f701681b3ef028cf5183a9693
# 	 diagnostics_Image-original_Dimensionality : 3D
# 	 diagnostics_Image-original_Spacing : (1.0, 1.0, 1.0)
# 	 diagnostics_Image-original_Size : (155, 240, 240)
# 	 diagnostics_Image-original_Mean : 222.13272681451613
# 	 diagnostics_Image-original_Minimum : 0.0
# 	 diagnostics_Image-original_Maximum : 4050.0
# 	 diagnostics_Mask-original_Hash : efdd43b17665e6f3098763188145c7de0c1507cc
# 	 diagnostics_Mask-original_Spacing : (1.0, 1.0, 1.0)
# 	 diagnostics_Mask-original_Size : (155, 240, 240)
# 	 diagnostics_Mask-original_BoundingBox : (34, 28, 81, 88, 91, 95)
# 	 diagnostics_Mask-original_VoxelNum : 449500
# 	 diagnostics_Mask-original_VolumeNum : 1
# 	 diagnostics_Mask-original_CenterOfMassIndex : (74.36432258064517, 74.93515239154617, 128.30991768631813)
# 	 diagnostics_Mask-original_CenterOfMass : (74.36432258064517, 74.93515239154617, 128.30991768631813)
# 	 original_shape_Elongation : 0.9156327728329408
# 	 original_shape_Flatness : 0.8825576124282378
# 	 original_shape_LeastAxisLength : 82.9967856190601
# 	 original_shape_MajorAxisLength : 94.0412098318496
# 	 original_shape_Maximum2DDiameterColumn : 102.9417310909429
# 	 original_shape_Maximum2DDiameterRow : 108.30050784737807
# 	 original_shape_Maximum2DDiameterSlice : 104.48444860360799
# 	 original_shape_Maximum3DDiameter : 114.69088891450794
# 	 original_shape_MeshVolume : 449423.9583333333
# 	 original_shape_MinorAxisLength : 86.10721371890087
# 	 original_shape_Sphericity : 0.7590428921374155
# 	 original_shape_SurfaceArea : 37381.37629410715
# 	 original_shape_SurfaceVolumeRatio : 0.08317619833338247
# 	 original_shape_VoxelVolume : 449500.0
# 	 original_firstorder_10Percentile : 0.0
# 	 original_firstorder_90Percentile : 2965.0
# 	 original_firstorder_Energy : 1292859349514.0
# 	 original_firstorder_Entropy : 5.812663547625503
# 	 original_firstorder_InterquartileRange : 2116.0
# 	 original_firstorder_Kurtosis : 1.997617939448581
# 	 original_firstorder_Maximum : 4050.0
# 	 original_firstorder_MeanAbsoluteDeviation : 903.3157469859502
# 	 original_firstorder_Mean : 1298.961895439377
# 	 original_firstorder_Median : 1231.0
# 	 original_firstorder_Minimum : 0.0
# 	 original_firstorder_Range : 4050.0
# 	 original_firstorder_RobustMeanAbsoluteDeviation : 773.3940726054785
# 	 original_firstorder_RootMeanSquared : 1695.9412056111726
# 	 original_firstorder_Skewness : 0.36020130154557134
# 	 original_firstorder_TotalEnergy : 1292859349514.0
# 	 original_firstorder_Uniformity : 0.08358807837159322
# 	 original_firstorder_Variance : 1188914.5670864182
# 	 original_glcm_Autocorrelation : 4682.196570694858
# 	 original_glcm_ClusterProminence : 111146679.98626798
# 	 original_glcm_ClusterShade : 223389.26911012403
# 	 original_glcm_ClusterTendency : 7473.519748036405
# 	 original_glcm_Contrast : 85.94172980675665
# 	 original_glcm_Correlation : 0.9772634418637174
# 	 original_glcm_DifferenceAverage : 4.771392185206614
# 	 original_glcm_DifferenceEntropy : 3.655980376115557
# 	 original_glcm_DifferenceVariance : 62.35048576724931
# 	 original_glcm_Id : 0.48534845394657017
# 	 original_glcm_Idm : 0.42567563034460676
# 	 original_glcm_Idmn : 0.9969444710043887
# 	 original_glcm_Idn : 0.9734389123914209
# 	 original_glcm_Imc1 : -0.3792370120917513
# 	 original_glcm_Imc2 : 0.9935768253401872
# 	 original_glcm_InverseVariance : 0.16270036104482496
# 	 original_glcm_JointAverage : 53.24725834772478
# 	 original_glcm_JointEnergy : 0.07011260566557319
# 	 original_glcm_JointEntropy : 9.482701284536516
# 	 original_glcm_MCC : 0.9787962902296123
# 	 original_glcm_MaximumProbability : 0.2641750977433349
# 	 original_glcm_SumAverage : 106.49451669544962
# 	 original_glcm_SumEntropy : 6.650153256607585
# 	 original_glcm_SumSquares : 1889.8653694607913
# 	 original_gldm_DependenceEntropy : 8.363277010971872
# 	 original_gldm_DependenceNonUniformity : 56018.190202447164
# 	 original_gldm_DependenceNonUniformityNormalized : 0.12462333749153985
# 	 original_gldm_DependenceVariance : 101.5541807358516
# 	 original_gldm_GrayLevelNonUniformity : 37572.841228031146
# 	 original_gldm_GrayLevelVariance : 1888.3814346388535
# 	 original_gldm_HighGrayLevelEmphasis : 4656.503468298109
# 	 original_gldm_LargeDependenceEmphasis : 188.59232925472747
# 	 original_gldm_LargeDependenceHighGrayLevelEmphasis : 68141.27179755284
# 	 original_gldm_LargeDependenceLowGrayLevelEmphasis : 177.13072996153306
# 	 original_gldm_LowGrayLevelEmphasis : 0.2804803650185864
# 	 original_gldm_SmallDependenceEmphasis : 0.22593111839625074
# 	 original_gldm_SmallDependenceHighGrayLevelEmphasis : 1417.9375527950458
# 	 original_gldm_SmallDependenceLowGrayLevelEmphasis : 0.0006808314908188375
# 	 original_glrlm_GrayLevelNonUniformity : 3161.513099909064
# 	 original_glrlm_GrayLevelNonUniformityNormalized : 0.010338634653586124
# 	 original_glrlm_GrayLevelVariance : 1308.051603373261
# 	 original_glrlm_HighGrayLevelRunEmphasis : 6267.808432838259
# 	 original_glrlm_LongRunEmphasis : 9.676223524405682
# 	 original_glrlm_LongRunHighGrayLevelEmphasis : 8246.56696352037
# 	 original_glrlm_LongRunLowGrayLevelEmphasis : 8.392489863905336
# 	 original_glrlm_LowGrayLevelRunEmphasis : 0.034517513215595555
# 	 original_glrlm_RunEntropy : 7.479811864200891
# 	 original_glrlm_RunLengthNonUniformity : 242387.97366162002
# 	 original_glrlm_RunLengthNonUniformityNormalized : 0.7930520357584953
# 	 original_glrlm_RunPercentage : 0.6796375459912724
# 	 original_glrlm_RunVariance : 7.506189668851194
# 	 original_glrlm_ShortRunEmphasis : 0.9067449867930039
# 	 original_glrlm_ShortRunHighGrayLevelEmphasis : 5878.45530216197
# 	 original_glrlm_ShortRunLowGrayLevelEmphasis : 0.0027563447900893026
# 	 original_glszm_GrayLevelNonUniformity : 963.4890181223212
# 	 original_glszm_GrayLevelNonUniformityNormalized : 0.00856754537802843
# 	 original_glszm_GrayLevelVariance : 1129.4782698824472
# 	 original_glszm_HighGrayLevelZoneEmphasis : 6295.338268509132
# 	 original_glszm_LargeAreaEmphasis : 141225.67157516585
# 	 original_glszm_LargeAreaHighGrayLevelEmphasis : 1610960.7955058778
# 	 original_glszm_LargeAreaLowGrayLevelEmphasis : 140890.67479901566
# 	 original_glszm_LowGrayLevelZoneEmphasis : 0.0007685166673852467
# 	 original_glszm_SizeZoneNonUniformity : 48899.437087623824
# 	 original_glszm_SizeZoneNonUniformityNormalized : 0.4348239972934235
# 	 original_glszm_SmallAreaEmphasis : 0.6857180037192362
# 	 original_glszm_SmallAreaHighGrayLevelEmphasis : 4226.07027888921
# 	 original_glszm_SmallAreaLowGrayLevelEmphasis : 0.0005326793397373601
# 	 original_glszm_ZoneEntropy : 8.929110707879637
# 	 original_glszm_ZonePercentage : 0.25018464961067854
# 	 original_glszm_ZoneVariance : 141209.69518415644
# 	 original_ngtdm_Busyness : 4.464795386305249
# 	 original_ngtdm_Coarseness : 3.135597322980189e-05
# 	 original_ngtdm_Complexity : 25580.57285714678
# 	 original_ngtdm_Contrast : 0.31061045640709656
# 	 original_ngtdm_Strength : 1.6584177325624085

# %%
len(result)
