# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import copy
from scipy.stats import wilcoxon, mannwhitneyu
import pickle as pkl

import nibabel as nib

import matplotlib.pyplot as plt 

from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import torch
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
def load_unet_result(path, _print):
    unet_df = pd.read_csv(path, index_col = 'Unnamed: 0')
    index_values = []
    for _index in unet_df.index:
        index_values.append(_index.split('-seg')[0])

    unet_df.index = index_values  
    unet_df.drop(['WT jaccard', 'TC jaccard', 'ET jaccard'], axis = 1, inplace = True)
    summary_unet_df = pd.DataFrame(zip(unet_df.mean().values.tolist(), 
                                       unet_df.std().values.tolist()), 
                                   columns = ['mean', 'std'], index = unet_df.columns)
    if _print:
        print("****UNet******")
        print(summary_unet_df)
    return summary_unet_df, unet_df

def load_nnunet_result(path, _print):
    with open(path, 'r') as file:
        data = json.load(file)

    WT = []
    TC = []
    ET = []
    file_name = []
    for case in data['metric_per_case']:
        WT.append(case['metrics']['(2, 1, 3)']['Dice'])
        TC.append(case['metrics']['(2, 3)']['Dice'])
        ET.append(case['metrics']['(3,)']['Dice'])
        file_name.append(case['reference_file'].split('/')[-1].split('.')[0])

    nnunet_df = pd.DataFrame(zip(WT, TC, ET), columns = ['WT dice', 'TC dice', 'ET dice'], 
                             index = file_name)
    summary_nnunet_df = pd.DataFrame(zip(nnunet_df.mean().values.tolist(), 
                                       nnunet_df.std().values.tolist()), 
                                   columns = ['mean', 'std'], index = nnunet_df.columns)
    if _print:
        print("****nnUNet******")
        print(summary_nnunet_df)
    return summary_nnunet_df, nnunet_df

def load_TransBTS_result(path, _print):
    with open(path, 'r') as file:
        data = json.load(file)

    WT = []
    TC = []
    ET = []
    file_name = []
    for case_id in data.keys():
        case = data[case_id]
        WT.append(case['WT'][0])
        TC.append(case['TC'][0])
        ET.append(case['ET'][0])
        file_name.append(case_id)

    TransBTS_df = pd.DataFrame(zip(WT, TC, ET), columns = ['WT dice', 'TC dice', 'ET dice'], 
                             index = file_name)
    summary_TransBTS_df = pd.DataFrame(zip(TransBTS_df.mean().values.tolist(), 
                                       TransBTS_df.std().values.tolist()), 
                                   columns = ['mean', 'std'], index = TransBTS_df.columns)
    if _print:
        print("****TransBTS******")
        print(summary_TransBTS_df)
    return summary_TransBTS_df, TransBTS_df

# %%
def read_results(_print=True):
    path = '../Results/Result/Vanilla_Unet/Unet_test_dice.csv'
    summary_unet_df, unet_df = load_unet_result(path, _print)

    path = '../Results/Result/nnUnet/nnUNetTrainer/summary.json'
    summary_da_nnunet_df, nnunet_da_df = load_nnunet_result(path, _print)

    path = '../Results/Result/nnUnet/nnUNetTrainerNoDA/summary.json'
    summary_noda_nnunet_df, nnunet_noda_df = load_nnunet_result(path, _print)

    path = '../Results/Result/TransBTS/submission/TransBTS2023-11-03/TransBTS_summary.json'
    summary_TransBTS_df, TransBTS_df = load_TransBTS_result(path, _print)
    return unet_df, nnunet_noda_df, nnunet_da_df, TransBTS_df

# %%
def get_overlaps(unet_df, TransBTS_df, nnunet_noda_df, WT_dice_threshold, TC_dice_threshold, ET_dice_threshold):
    unet_df_sub = unet_df[(unet_df['WT dice'] < WT_dice_threshold) 
                          & (unet_df['TC dice'] < TC_dice_threshold) 
                          & (unet_df['ET dice'] < ET_dice_threshold)]
    
    TransBTS_df_sub = TransBTS_df[(TransBTS_df['WT dice'] < WT_dice_threshold) 
                          & (TransBTS_df['TC dice'] < TC_dice_threshold) 
                          & (TransBTS_df['ET dice'] < ET_dice_threshold)]
    
    nnunet_noda_df_sub = nnunet_noda_df[(nnunet_noda_df['WT dice'] < WT_dice_threshold) 
                          & (nnunet_noda_df['TC dice'] < TC_dice_threshold) 
                          & (nnunet_noda_df['ET dice'] < ET_dice_threshold)]

    unet_df_sub_subjects = unet_df_sub.index.values.tolist()
    TransBTS_df_sub_subjects = TransBTS_df_sub.index.values.tolist()
    nnunet_noda_df_sub_subjects = nnunet_noda_df_sub.index.values.tolist()

    all_overlaps = list(set(unet_df_sub_subjects) & set(TransBTS_df_sub_subjects) & set(nnunet_noda_df_sub_subjects))
    print('all overlap', len(all_overlaps), unet_df_sub.shape, nnunet_noda_df_sub.shape)

    unet_nnunet_overlaps = list(set(unet_df_sub_subjects) & set(nnunet_noda_df_sub_subjects))
    print('unet-nnunet overlap', len(unet_nnunet_overlaps))

    unet_TransBTS_overlaps = list(set(unet_df_sub_subjects) & set(TransBTS_df_sub_subjects))
    print('unet-TransBTS overlap', len(unet_TransBTS_overlaps))

    nnunet_TransBTS_overlaps = list(set(TransBTS_df_sub_subjects) & set(nnunet_noda_df_sub_subjects))
    print('nnunet-TransBTS overlap', len(nnunet_TransBTS_overlaps))
    
    return all_overlaps, unet_nnunet_overlaps

# %%
def read_radiomics_results(analysis_type):
    file_name = '../Results/Analysis_Results/Radiomics/Tumor/' + analysis_type + '.pkl'
    with open(file_name, 'rb') as f:
        results = pkl.load(f)
    return results

def read_MRI(dataset, patient_id):
    if dataset == 'Brats2020':
        baseloc = '../input/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
        pefix = 'BraTS20_Training_' + patient_id + '/' + 'BraTS20_Training_' + patient_id
        suffixs = ['_flair.nii','_t2.nii', '_t1.nii', '_t1ce.nii', '_seg.nii']
    elif dataset == 'Brats2023':
        baseloc = '../input/Brats2023/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/'
        pefix = patient_id + '/' + patient_id
        suffixs = ['-t2f.nii.gz','-t2w.nii.gz', '-t1n.nii.gz', '-t1c.nii.gz', '-seg.nii.gz']

    flair_filename = baseloc + pefix + suffixs[0]
    flair_img_f = nib.load(flair_filename)
    flair_img = np.asarray(flair_img_f.dataobj)

    t2_filename = baseloc + pefix + suffixs[1]
    t2_img_f = nib.load(t2_filename)
    t2_img = np.asarray(t2_img_f.dataobj)

    t1_filename = baseloc + pefix + suffixs[2]
    t1_img_f = nib.load(t1_filename)
    t1_img = np.asarray(t1_img_f.dataobj)

    t1ce_filename = baseloc + pefix + suffixs[3]
    t1ce_img_f = nib.load(t1ce_filename)
    t1ce_img = np.asarray(t1ce_img_f.dataobj)
    
    mask_filename = baseloc + pefix + suffixs[4]
    mask_img_f = nib.load(mask_filename)
    mask_img = np.asarray(mask_img_f.dataobj)
    
    return flair_img, t2_img, t1_img, t1ce_img, mask_img 

def preprocess_mask_labels(mask):
    # whole tumour
    mask_WT = mask.copy()
    mask_WT[mask_WT == 1] = 1
    mask_WT[mask_WT == 2] = 1
    mask_WT[mask_WT == 3] = 1
    # include all tumours 

    # NCR / NET - LABEL 1
    mask_TC = mask.copy()
    mask_TC[mask_TC == 1] = 1
    mask_TC[mask_TC == 2] = 0
    mask_TC[mask_TC == 3] = 1
    # exclude 2 / 4 labelled tumour 

    # ET - LABEL 4 
    mask_ET = mask.copy()
    mask_ET[mask_ET == 1] = 0
    mask_ET[mask_ET == 2] = 0
    mask_ET[mask_ET == 3] = 1
    # exclude 2 / 1 labelled tumour 

    mask = np.stack([mask_WT, mask_TC, mask_ET])
    
    return mask 

def read_mask_file(patient_id):
    baseloc = '../input/Brats2023/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/'
    pefix = patient_id + '/' + patient_id
    suffixs = ['-t2f.nii.gz','-t2w.nii.gz', '-t1n.nii.gz', '-t1c.nii.gz', '-seg.nii.gz']
    outputloc = '../Results/Result/Vanilla_Unet/' + patient_id
    
    sample_filename_mask = baseloc + pefix + suffixs[4]
    sample_mask_f = nib.load(sample_filename_mask)
    sample_mask = np.asarray(sample_mask_f.dataobj)
    
    masks = preprocess_mask_labels(sample_mask)
    mask_WT, mask_TC, mask_ET = masks[0], masks[1], masks[2]
    
    return mask_WT

def remove_duplicate_columns(df):
    """
    Remove columns from a DataFrame that have identical values to other columns, regardless of the column name.
    
    Parameters:
    - df: The pandas DataFrame from which to remove duplicate columns.
    
    Returns:
    - A new DataFrame with duplicate columns removed.
    """
    columns_to_remove = set()
    for i in range(df.shape[1]): # Iterate over all columns
        for j in range(i + 1, df.shape[1]): # Compare each column with every other column
            # Check if not already identified as duplicate and if equal
            if i not in columns_to_remove and j not in columns_to_remove:
                if df.iloc[:, i].equals(df.iloc[:, j]):
                    columns_to_remove.add(j)
    
    # Create a new DataFrame without the duplicate columns
    df_cleaned = df.drop(columns=df.columns[list(columns_to_remove)])
    return df_cleaned

# %%
WT_dice_threshold= 0.91
TC_dice_threshold= 0.86
ET_dice_threshold= 0.85

# WT_dice_threshold= 0.9
# TC_dice_threshold= 0.9
# ET_dice_threshold= 0.9

analysis_types = ['firstorder', 'glcm_1', 
                  'glcm_5', 
                  'glcm_10', 
                  'gldm_1', 'gldm_5',
                  'gldm_10', 
                  'glrlm', 
                  'glszm', 'intensity', 
                  'ngtdm_1', 'ngtdm_5',
                  'ngtdm_10',
                  'shape', 'size' ]

unet_df, nnunet_noda_df, nnunet_da_df, TransBTS_df = read_results(False)

all_overlaps, unet_nnunet_overlaps = get_overlaps(unet_df, 
                                                TransBTS_df, 
                                                nnunet_noda_df, 
                                                WT_dice_threshold, 
                                                TC_dice_threshold, 
                                                ET_dice_threshold)
# Out:
# all overlap 42 (157, 3) (47, 3)
# unet-nnunet overlap 47
# unet-TransBTS overlap 93
# nnunet-TransBTS overlap 42

# %%
results_df = unet_df
for analysis_type in analysis_types:
    try:
        radiomics_results_df = read_radiomics_results(analysis_type)
    except:
        continue
    properties = {}
    property_df = pd.DataFrame()
    for i in range(len(radiomics_results_df.keys())):
        key = list(radiomics_results_df.keys())[i]
        properties[i] = key
#         print('properties ', i, ':', key)

    for i in range(len(properties)):
        selected_property = properties[i]

        property_result_df = pd.DataFrame.from_dict(radiomics_results_df[selected_property], 
                                                    orient = 'index').astype(float)
        new_col = []
        for col in property_result_df.columns:
            new_col.append(selected_property + '_' + col + '_' + analysis_type)
        property_result_df.columns = new_col
        results_df = pd.merge(property_result_df, 
                       results_df, 
                       left_index=True, 
                       right_index=True)

# %%
unet_df_bad = results_df[(results_df['WT dice'] < WT_dice_threshold) 
                          & (results_df['TC dice'] < TC_dice_threshold) 
                          & (results_df['ET dice'] < ET_dice_threshold)]
# unet_df_bad = unet_df_bad[unet_df_bad.index.isin(unet_nnunet_overlaps)]
unet_df_bad['dice'] = ['bad']*unet_df_bad.shape[0]

unet_df_good = results_df[(results_df['WT dice'] >= WT_dice_threshold) 
                       & (results_df['TC dice'] >= TC_dice_threshold)]
unet_df_good['dice'] = ['good']*unet_df_good.shape[0]


prediction_df = pd.concat([unet_df_good, unet_df_bad])
prediction_df.shape
# Out:
# /var/folders/_h/ng9pq_61611_ps5d9w4sbv0m0000gq/T/ipykernel_57231/4290878925.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unet_df_bad['dice'] = ['bad']*unet_df_bad.shape[0]
# /var/folders/_h/ng9pq_61611_ps5d9w4sbv0m0000gq/T/ipykernel_57231/4290878925.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unet_df_good['dice'] = ['good']*unet_df_good.shape[0]
# (653, 792)

# %%
summary_df = pd.read_csv('../Results/Analysis_Results/Radiomics/summary/Tumor_summary.csv')
summary_df['property'] = summary_df['property'] + '_' +summary_df['Unnamed: 0'] + '_' +summary_df['analysis_type']

important_features = summary_df[(summary_df['Statistically_Different'] != '-') 
                                & ((summary_df['Effect_Size'] == 'Large') | (summary_df['Effect_Size'] == 'Medium') | (summary_df['Effect_Size'] == 'Small'))].property.values.tolist()

# important_features = summary_df[(summary_df['Statistically_Different'] != '-') 
#                                 & ((summary_df['Effect_Size'] == 'Large') | (summary_df['Effect_Size'] == 'Medium'))].property.values.tolist()

# important_features = summary_df[(summary_df['Statistically_Different'] != '-') 
#                                 & ((summary_df['Effect_Size'] == 'Large'))].property.values.tolist()

important_features.append('dice')
print(len(important_features))
for feature in prediction_df.columns: 
    if feature not in important_features:
        prediction_df = prediction_df.drop(feature, axis = 1)
prediction_df.shape
# Out:
# 485
# (653, 485)

# %%
prediction_df = remove_duplicate_columns(prediction_df)
# prediction_df = prediction_df.drop(['WT dice', 'TC dice', 'ET dice'], axis = 1)
prediction_df.reset_index(inplace=True, drop=True)

# %%
from sklearn.metrics import f1_score
from pytorch_tabnet.metrics import Metric
from pytorch_tabnet.augmentations import ClassificationSMOTE
import scipy

aug = ClassificationSMOTE(p=0.2)

class Gini(Metric):
    def __init__(self):
        self._name = "f1"
        self._maximize = True

    def __call__(self, y_true, y_score):
#         print(y_true)
        y_score = np.argmax(y_score, axis = 1)
        f1 = f1_score(y_true, y_score, pos_label=0)
        return f1

# Separate features and target variable
X = prediction_df.drop('dice', axis=1)  # Feature matrix
y = prediction_df['dice']  # Target variable

# Initialize the Stratified K-Fold cross-validator
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Lists to store results of each fold
accuracies = []
conf_matrices = []

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# X_scaled = pd.DataFrame(X_scaled, columns = X.columns)
# X_scaled = X

# Stratified K-Fold Cross-Validation
for train_index, test_index in skf.split(X_scaled, y):
    # Split data
    X_train, X_test = X_scaled[train_index], X_scaled[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    
    X_train = scipy.sparse.csr_matrix(X_train)  # Create a CSR matrix from X_train
    X_val = scipy.sparse.csr_matrix(X_val)  # Create a CSR matrix from X_valid
    X_test = scipy.sparse.csr_matrix(X_test)
    
    clf = TabNetClassifier(optimizer_params=dict(lr=2e-2), scheduler_params={"step_size":50, "gamma":0.9}, 
                       scheduler_fn=torch.optim.lr_scheduler.StepLR, verbose=1)

    # Fit the model
    clf.fit(
      X_train=X_train, y_train=y_train,
      eval_set=[(X_train, y_train), (X_val, y_val)],
      eval_name=['train', 'valid'],
      eval_metric=['gini'],
      max_epochs=1000 , patience=50,
      batch_size=64, virtual_batch_size=32,
      num_workers=0,
      weights=1,
      drop_last=False
    )
    
    y_pred = clf.predict(X_test)
    
    # Evaluate the classifier
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    conf_matrices.append(confusion_matrix(y_test, y_pred))
    
    # Optionally, print out the classification report for each fold
    print(classification_report(y_test, y_pred))

# Display the average accuracy across all folds
print(f'Average Accuracy: {np.mean(accuracies):.4f}')

# You can also analyze the confusion matrices to understand the model's performance in more detail.
# Out:
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.80356 | train_gini: 0.3871  | valid_gini: 0.38961 |  0:00:00s
# epoch 1  | loss: 0.74343 | train_gini: 0.46886 | valid_gini: 0.4058  |  0:00:00s
# epoch 2  | loss: 0.7253  | train_gini: 0.28125 | valid_gini: 0.26667 |  0:00:00s
# epoch 3  | loss: 0.69984 | train_gini: 0.27941 | valid_gini: 0.2069  |  0:00:01s
# epoch 4  | loss: 0.67644 | train_gini: 0.28966 | valid_gini: 0.375   |  0:00:01s
# epoch 5  | loss: 0.66551 | train_gini: 0.26154 | valid_gini: 0.2069  |  0:00:01s
# epoch 6  | loss: 0.66269 | train_gini: 0.45399 | valid_gini: 0.55    |  0:00:02s
# epoch 7  | loss: 0.64281 | train_gini: 0.52222 | valid_gini: 0.39024 |  0:00:02s
# epoch 8  | loss: 0.59619 | train_gini: 0.46632 | valid_gini: 0.38095 |  0:00:02s
# epoch 9  | loss: 0.6351  | train_gini: 0.59055 | valid_gini: 0.50746 |  0:00:03s
# epoch 10 | loss: 0.57782 | train_gini: 0.59075 | valid_gini: 0.50746 |  0:00:03s
# epoch 11 | loss: 0.58773 | train_gini: 0.59206 | valid_gini: 0.58824 |  0:00:03s
# epoch 12 | loss: 0.54169 | train_gini: 0.58394 | valid_gini: 0.47222 |  0:00:04s
# epoch 13 | loss: 0.5306  | train_gini: 0.59136 | valid_gini: 0.51282 |  0:00:04s
# epoch 14 | loss: 0.51311 | train_gini: 0.6     | valid_gini: 0.52174 |  0:00:04s
# epoch 15 | loss: 0.53299 | train_gini: 0.5977  | valid_gini: 0.56667 |  0:00:05s
# epoch 16 | loss: 0.52407 | train_gini: 0.62044 | valid_gini: 0.63492 |  0:00:05s
# epoch 17 | loss: 0.53954 | train_gini: 0.64889 | valid_gini: 0.66667 |  0:00:05s
# epoch 18 | loss: 0.5094  | train_gini: 0.70833 | valid_gini: 0.64516 |  0:00:06s
# epoch 19 | loss: 0.43204 | train_gini: 0.71366 | valid_gini: 0.67797 |  0:00:06s
# epoch 20 | loss: 0.48503 | train_gini: 0.72247 | valid_gini: 0.63158 |  0:00:06s
# epoch 21 | loss: 0.43847 | train_gini: 0.73043 | valid_gini: 0.65517 |  0:00:07s
# epoch 22 | loss: 0.48205 | train_gini: 0.70813 | valid_gini: 0.68    |  0:00:07s
# epoch 23 | loss: 0.45283 | train_gini: 0.70423 | valid_gini: 0.65385 |  0:00:07s
# epoch 24 | loss: 0.39476 | train_gini: 0.72811 | valid_gini: 0.65385 |  0:00:08s
# epoch 25 | loss: 0.37997 | train_gini: 0.73488 | valid_gini: 0.60377 |  0:00:08s
# epoch 26 | loss: 0.42468 | train_gini: 0.7713  | valid_gini: 0.66667 |  0:00:08s
# epoch 27 | loss: 0.43585 | train_gini: 0.76033 | valid_gini: 0.63333 |  0:00:08s
# epoch 28 | loss: 0.36353 | train_gini: 0.76423 | valid_gini: 0.64516 |  0:00:09s
# epoch 29 | loss: 0.42097 | train_gini: 0.80349 | valid_gini: 0.68852 |  0:00:09s
# epoch 30 | loss: 0.33792 | train_gini: 0.75229 | valid_gini: 0.66667 |  0:00:09s
# epoch 31 | loss: 0.33717 | train_gini: 0.78673 | valid_gini: 0.67925 |  0:00:10s
# epoch 32 | loss: 0.36128 | train_gini: 0.82667 | valid_gini: 0.71186 |  0:00:10s
# epoch 33 | loss: 0.33445 | train_gini: 0.79821 | valid_gini: 0.72727 |  0:00:10s
# epoch 34 | loss: 0.34033 | train_gini: 0.84466 | valid_gini: 0.7451  |  0:00:11s
# epoch 35 | loss: 0.3471  | train_gini: 0.82927 | valid_gini: 0.73469 |  0:00:11s
# epoch 36 | loss: 0.27422 | train_gini: 0.8125  | valid_gini: 0.75862 |  0:00:11s
# epoch 37 | loss: 0.33872 | train_gini: 0.78788 | valid_gini: 0.71186 |  0:00:12s
# epoch 38 | loss: 0.3433  | train_gini: 0.73684 | valid_gini: 0.66667 |  0:00:12s
# epoch 39 | loss: 0.42411 | train_gini: 0.80569 | valid_gini: 0.69091 |  0:00:12s
# epoch 40 | loss: 0.35696 | train_gini: 0.82828 | valid_gini: 0.73469 |  0:00:13s
# epoch 41 | loss: 0.35151 | train_gini: 0.84112 | valid_gini: 0.7451  |  0:00:13s
# epoch 42 | loss: 0.33979 | train_gini: 0.83871 | valid_gini: 0.76923 |  0:00:13s
# epoch 43 | loss: 0.31006 | train_gini: 0.85973 | valid_gini: 0.76923 |  0:00:13s
# epoch 44 | loss: 0.24767 | train_gini: 0.83262 | valid_gini: 0.78571 |  0:00:14s
# epoch 45 | loss: 0.29773 | train_gini: 0.83478 | valid_gini: 0.71186 |  0:00:14s
# epoch 46 | loss: 0.34065 | train_gini: 0.83621 | valid_gini: 0.70175 |  0:00:14s
# epoch 47 | loss: 0.28114 | train_gini: 0.78689 | valid_gini: 0.72131 |  0:00:15s
# epoch 48 | loss: 0.24824 | train_gini: 0.82051 | valid_gini: 0.73684 |  0:00:15s
# epoch 49 | loss: 0.31535 | train_gini: 0.85854 | valid_gini: 0.73469 |  0:00:15s
# epoch 50 | loss: 0.28754 | train_gini: 0.85981 | valid_gini: 0.69231 |  0:00:16s
# epoch 51 | loss: 0.23643 | train_gini: 0.86878 | valid_gini: 0.69091 |  0:00:16s
# epoch 52 | loss: 0.26708 | train_gini: 0.86275 | valid_gini: 0.77551 |  0:00:16s
# epoch 53 | loss: 0.29065 | train_gini: 0.86385 | valid_gini: 0.71429 |  0:00:17s
# epoch 54 | loss: 0.2646  | train_gini: 0.86607 | valid_gini: 0.71186 |  0:00:17s
# epoch 55 | loss: 0.28417 | train_gini: 0.87783 | valid_gini: 0.75    |  0:00:17s
# epoch 56 | loss: 0.20228 | train_gini: 0.86878 | valid_gini: 0.75    |  0:00:17s
# epoch 57 | loss: 0.24216 | train_gini: 0.85217 | valid_gini: 0.73333 |  0:00:18s
# epoch 58 | loss: 0.23859 | train_gini: 0.82192 | valid_gini: 0.74074 |  0:00:18s
# epoch 59 | loss: 0.24082 | train_gini: 0.84906 | valid_gini: 0.77778 |  0:00:18s
# epoch 60 | loss: 0.2322  | train_gini: 0.86385 | valid_gini: 0.75472 |  0:00:19s
# epoch 61 | loss: 0.21718 | train_gini: 0.82819 | valid_gini: 0.73684 |  0:00:19s
# epoch 62 | loss: 0.26481 | train_gini: 0.81385 | valid_gini: 0.71186 |  0:00:19s
# epoch 63 | loss: 0.26533 | train_gini: 0.85185 | valid_gini: 0.70175 |  0:00:20s
# epoch 64 | loss: 0.27339 | train_gini: 0.86239 | valid_gini: 0.72414 |  0:00:20s
# epoch 65 | loss: 0.24584 | train_gini: 0.86239 | valid_gini: 0.77193 |  0:00:20s
# epoch 66 | loss: 0.20992 | train_gini: 0.86111 | valid_gini: 0.74576 |  0:00:21s
# epoch 67 | loss: 0.18201 | train_gini: 0.88    | valid_gini: 0.74576 |  0:00:21s
# epoch 68 | loss: 0.26403 | train_gini: 0.88584 | valid_gini: 0.77193 |  0:00:21s
# epoch 69 | loss: 0.15967 | train_gini: 0.89202 | valid_gini: 0.76364 |  0:00:22s
# epoch 70 | loss: 0.23932 | train_gini: 0.87324 | valid_gini: 0.76364 |  0:00:22s
# epoch 71 | loss: 0.24652 | train_gini: 0.88182 | valid_gini: 0.79245 |  0:00:22s
# epoch 72 | loss: 0.17963 | train_gini: 0.875   | valid_gini: 0.73684 |  0:00:23s
# epoch 73 | loss: 0.18889 | train_gini: 0.90233 | valid_gini: 0.74074 |  0:00:23s
# epoch 74 | loss: 0.26775 | train_gini: 0.90732 | valid_gini: 0.7451  |  0:00:23s
# epoch 75 | loss: 0.24736 | train_gini: 0.9064  | valid_gini: 0.77551 |  0:00:24s
# epoch 76 | loss: 0.25025 | train_gini: 0.891   | valid_gini: 0.74074 |  0:00:24s
# epoch 77 | loss: 0.25126 | train_gini: 0.89908 | valid_gini: 0.75862 |  0:00:24s
# epoch 78 | loss: 0.17663 | train_gini: 0.91589 | valid_gini: 0.75862 |  0:00:25s
# epoch 79 | loss: 0.14337 | train_gini: 0.8972  | valid_gini: 0.73684 |  0:00:25s
# epoch 80 | loss: 0.19235 | train_gini: 0.90196 | valid_gini: 0.74074 |  0:00:25s
# epoch 81 | loss: 0.19424 | train_gini: 0.87619 | valid_gini: 0.77778 |  0:00:26s
# epoch 82 | loss: 0.19207 | train_gini: 0.891   | valid_gini: 0.75    |  0:00:26s
# epoch 83 | loss: 0.18863 | train_gini: 0.89498 | valid_gini: 0.8     |  0:00:26s
# epoch 84 | loss: 0.20593 | train_gini: 0.91509 | valid_gini: 0.74576 |  0:00:27s
# epoch 85 | loss: 0.20735 | train_gini: 0.91589 | valid_gini: 0.76364 |  0:00:27s
# epoch 86 | loss: 0.16875 | train_gini: 0.91589 | valid_gini: 0.75    |  0:00:27s
# epoch 87 | loss: 0.18577 | train_gini: 0.90047 | valid_gini: 0.80769 |  0:00:28s
# epoch 88 | loss: 0.19785 | train_gini: 0.92523 | valid_gini: 0.76364 |  0:00:28s
# epoch 89 | loss: 0.21644 | train_gini: 0.88789 | valid_gini: 0.72727 |  0:00:28s
# epoch 90 | loss: 0.20048 | train_gini: 0.87387 | valid_gini: 0.71186 |  0:00:28s
# epoch 91 | loss: 0.20309 | train_gini: 0.92093 | valid_gini: 0.77193 |  0:00:29s
# epoch 92 | loss: 0.17604 | train_gini: 0.92308 | valid_gini: 0.81481 |  0:00:29s
# epoch 93 | loss: 0.18789 | train_gini: 0.93596 | valid_gini: 0.80769 |  0:00:29s
# epoch 94 | loss: 0.21285 | train_gini: 0.93659 | valid_gini: 0.77778 |  0:00:30s
# epoch 95 | loss: 0.17497 | train_gini: 0.91509 | valid_gini: 0.83636 |  0:00:30s
# epoch 96 | loss: 0.13562 | train_gini: 0.95192 | valid_gini: 0.80769 |  0:00:30s
# epoch 97 | loss: 0.16019 | train_gini: 0.94231 | valid_gini: 0.76923 |  0:00:31s
# epoch 98 | loss: 0.14098 | train_gini: 0.93269 | valid_gini: 0.74074 |  0:00:31s
# epoch 99 | loss: 0.16019 | train_gini: 0.90476 | valid_gini: 0.71698 |  0:00:31s
# epoch 100| loss: 0.18381 | train_gini: 0.91429 | valid_gini: 0.72727 |  0:00:32s
# epoch 101| loss: 0.15573 | train_gini: 0.93659 | valid_gini: 0.73077 |  0:00:32s
# epoch 102| loss: 0.15789 | train_gini: 0.95567 | valid_gini: 0.69565 |  0:00:32s
# epoch 103| loss: 0.12435 | train_gini: 0.95098 | valid_gini: 0.75472 |  0:00:33s
# epoch 104| loss: 0.11671 | train_gini: 0.93269 | valid_gini: 0.76923 |  0:00:33s
# epoch 105| loss: 0.18774 | train_gini: 0.92233 | valid_gini: 0.74074 |  0:00:33s
# epoch 106| loss: 0.14655 | train_gini: 0.94634 | valid_gini: 0.75472 |  0:00:33s
# epoch 107| loss: 0.12341 | train_gini: 0.95652 | valid_gini: 0.73077 |  0:00:34s
# epoch 108| loss: 0.16725 | train_gini: 0.93839 | valid_gini: 0.76923 |  0:00:34s
# epoch 109| loss: 0.15794 | train_gini: 0.9372  | valid_gini: 0.76    |  0:00:34s
# epoch 110| loss: 0.17762 | train_gini: 0.95652 | valid_gini: 0.77551 |  0:00:35s
# epoch 111| loss: 0.13671 | train_gini: 0.95146 | valid_gini: 0.75472 |  0:00:35s
# epoch 112| loss: 0.12398 | train_gini: 0.95238 | valid_gini: 0.70175 |  0:00:35s
# epoch 113| loss: 0.12867 | train_gini: 0.95652 | valid_gini: 0.71698 |  0:00:36s
# epoch 114| loss: 0.18459 | train_gini: 0.9561  | valid_gini: 0.72727 |  0:00:36s
# epoch 115| loss: 0.15002 | train_gini: 0.97087 | valid_gini: 0.76    |  0:00:36s
# epoch 116| loss: 0.15424 | train_gini: 0.96117 | valid_gini: 0.76923 |  0:00:36s
# epoch 117| loss: 0.10839 | train_gini: 0.96117 | valid_gini: 0.70588 |  0:00:37s
# epoch 118| loss: 0.11142 | train_gini: 0.94686 | valid_gini: 0.7451  |  0:00:37s
# epoch 119| loss: 0.11798 | train_gini: 0.95652 | valid_gini: 0.76923 |  0:00:37s
# epoch 120| loss: 0.11213 | train_gini: 0.92823 | valid_gini: 0.71698 |  0:00:38s
# epoch 121| loss: 0.12544 | train_gini: 0.9378  | valid_gini: 0.7451  |  0:00:38s
# epoch 122| loss: 0.14528 | train_gini: 0.96117 | valid_gini: 0.72    |  0:00:38s
# epoch 123| loss: 0.14178 | train_gini: 0.9703  | valid_gini: 0.76596 |  0:00:39s
# epoch 124| loss: 0.12608 | train_gini: 0.95431 | valid_gini: 0.76596 |  0:00:39s
# epoch 125| loss: 0.11907 | train_gini: 0.96585 | valid_gini: 0.8     |  0:00:39s
# epoch 126| loss: 0.12943 | train_gini: 0.95098 | valid_gini: 0.81633 |  0:00:40s
# epoch 127| loss: 0.09584 | train_gini: 0.96078 | valid_gini: 0.81633 |  0:00:40s
# epoch 128| loss: 0.08578 | train_gini: 0.96    | valid_gini: 0.8     |  0:00:40s
# epoch 129| loss: 0.09989 | train_gini: 0.98    | valid_gini: 0.80851 |  0:00:41s
# epoch 130| loss: 0.12789 | train_gini: 0.97512 | valid_gini: 0.76596 |  0:00:41s
# epoch 131| loss: 0.08244 | train_gini: 0.96552 | valid_gini: 0.81633 |  0:00:41s
# epoch 132| loss: 0.08526 | train_gini: 0.95522 | valid_gini: 0.78431 |  0:00:41s
# epoch 133| loss: 0.09724 | train_gini: 0.93596 | valid_gini: 0.78431 |  0:00:42s
# epoch 134| loss: 0.21481 | train_gini: 0.94118 | valid_gini: 0.75472 |  0:00:42s
# epoch 135| loss: 0.16118 | train_gini: 0.95146 | valid_gini: 0.77778 |  0:00:43s
# epoch 136| loss: 0.15123 | train_gini: 0.92891 | valid_gini: 0.75    |  0:00:43s
# epoch 137| loss: 0.20246 | train_gini: 0.93396 | valid_gini: 0.78571 |  0:00:43s
# epoch 138| loss: 0.14365 | train_gini: 0.93839 | valid_gini: 0.77778 |  0:00:44s
# epoch 139| loss: 0.12742 | train_gini: 0.9434  | valid_gini: 0.76923 |  0:00:44s
# epoch 140| loss: 0.15539 | train_gini: 0.95694 | valid_gini: 0.78431 |  0:00:44s
# epoch 141| loss: 0.17625 | train_gini: 0.94231 | valid_gini: 0.76923 |  0:00:45s
# epoch 142| loss: 0.14415 | train_gini: 0.96585 | valid_gini: 0.77778 |  0:00:45s
# epoch 143| loss: 0.10592 | train_gini: 0.94686 | valid_gini: 0.75    |  0:00:45s
# epoch 144| loss: 0.16447 | train_gini: 0.95098 | valid_gini: 0.78571 |  0:00:46s
# epoch 145| loss: 0.15239 | train_gini: 0.96585 | valid_gini: 0.79245 |  0:00:46s
#
# Early stopping occurred at epoch 145 with best_epoch = 95 and best_valid_gini = 0.83636
#               precision    recall  f1-score   support
#
#          bad       0.59      0.61      0.60        31
#         good       0.88      0.87      0.87       100
#
#     accuracy                           0.81       131
#    macro avg       0.74      0.74      0.74       131
# weighted avg       0.81      0.81      0.81       131
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.90396 | train_gini: 0.37209 | valid_gini: 0.43299 |  0:00:00s
# epoch 1  | loss: 0.80432 | train_gini: 0.40412 | valid_gini: 0.40678 |  0:00:00s
# epoch 2  | loss: 0.68815 | train_gini: 0.38376 | valid_gini: 0.2807  |  0:00:01s
# epoch 3  | loss: 0.65421 | train_gini: 0.45045 | valid_gini: 0.32558 |  0:00:01s
# epoch 4  | loss: 0.6995  | train_gini: 0.48627 | valid_gini: 0.4     |  0:00:01s
# epoch 5  | loss: 0.6573  | train_gini: 0.54472 | valid_gini: 0.44    |  0:00:01s
# epoch 6  | loss: 0.65751 | train_gini: 0.47343 | valid_gini: 0.47619 |  0:00:02s
# epoch 7  | loss: 0.68164 | train_gini: 0.43979 | valid_gini: 0.36842 |  0:00:02s
# epoch 8  | loss: 0.69103 | train_gini: 0.47368 | valid_gini: 0.37209 |  0:00:02s
# epoch 9  | loss: 0.64906 | train_gini: 0.52695 | valid_gini: 0.45946 |  0:00:03s
# epoch 10 | loss: 0.63193 | train_gini: 0.54662 | valid_gini: 0.40541 |  0:00:03s
# epoch 11 | loss: 0.53393 | train_gini: 0.55973 | valid_gini: 0.45714 |  0:00:03s
# epoch 12 | loss: 0.58213 | train_gini: 0.59259 | valid_gini: 0.5     |  0:00:04s
# epoch 13 | loss: 0.62023 | train_gini: 0.57708 | valid_gini: 0.54237 |  0:00:04s
# epoch 14 | loss: 0.56211 | train_gini: 0.57455 | valid_gini: 0.46154 |  0:00:04s
# epoch 15 | loss: 0.54409 | train_gini: 0.59649 | valid_gini: 0.54237 |  0:00:05s
# epoch 16 | loss: 0.49702 | train_gini: 0.64314 | valid_gini: 0.51852 |  0:00:05s
# epoch 17 | loss: 0.58219 | train_gini: 0.62222 | valid_gini: 0.51064 |  0:00:05s
# epoch 18 | loss: 0.56935 | train_gini: 0.59322 | valid_gini: 0.52    |  0:00:06s
# epoch 19 | loss: 0.51087 | train_gini: 0.64486 | valid_gini: 0.54167 |  0:00:06s
# epoch 20 | loss: 0.54425 | train_gini: 0.592   | valid_gini: 0.45614 |  0:00:06s
# epoch 21 | loss: 0.58609 | train_gini: 0.59701 | valid_gini: 0.47761 |  0:00:06s
# epoch 22 | loss: 0.51503 | train_gini: 0.62559 | valid_gini: 0.47619 |  0:00:07s
# epoch 23 | loss: 0.48868 | train_gini: 0.62069 | valid_gini: 0.4898  |  0:00:07s
# epoch 24 | loss: 0.5077  | train_gini: 0.65587 | valid_gini: 0.52632 |  0:00:07s
# epoch 25 | loss: 0.44229 | train_gini: 0.656   | valid_gini: 0.54545 |  0:00:08s
# epoch 26 | loss: 0.44073 | train_gini: 0.6749  | valid_gini: 0.63333 |  0:00:08s
# epoch 27 | loss: 0.40904 | train_gini: 0.68571 | valid_gini: 0.60714 |  0:00:08s
# epoch 28 | loss: 0.44395 | train_gini: 0.69048 | valid_gini: 0.63158 |  0:00:09s
# epoch 29 | loss: 0.37078 | train_gini: 0.70042 | valid_gini: 0.69231 |  0:00:09s
# epoch 30 | loss: 0.42007 | train_gini: 0.70476 | valid_gini: 0.59091 |  0:00:09s
# epoch 31 | loss: 0.42374 | train_gini: 0.7032  | valid_gini: 0.59091 |  0:00:10s
# epoch 32 | loss: 0.43461 | train_gini: 0.68966 | valid_gini: 0.59091 |  0:00:10s
# epoch 33 | loss: 0.44953 | train_gini: 0.7343  | valid_gini: 0.66667 |  0:00:10s
# epoch 34 | loss: 0.41939 | train_gini: 0.75117 | valid_gini: 0.65306 |  0:00:11s
# epoch 35 | loss: 0.39361 | train_gini: 0.72    | valid_gini: 0.58824 |  0:00:11s
# epoch 36 | loss: 0.4283  | train_gini: 0.71616 | valid_gini: 0.57143 |  0:00:11s
# epoch 37 | loss: 0.38623 | train_gini: 0.76364 | valid_gini: 0.625   |  0:00:12s
# epoch 38 | loss: 0.44329 | train_gini: 0.72727 | valid_gini: 0.64516 |  0:00:12s
# epoch 39 | loss: 0.43502 | train_gini: 0.75325 | valid_gini: 0.66667 |  0:00:12s
# epoch 40 | loss: 0.39624 | train_gini: 0.76142 | valid_gini: 0.60465 |  0:00:13s
# epoch 41 | loss: 0.34928 | train_gini: 0.7265  | valid_gini: 0.62745 |  0:00:13s
# epoch 42 | loss: 0.42772 | train_gini: 0.74138 | valid_gini: 0.64    |  0:00:14s
# epoch 43 | loss: 0.33582 | train_gini: 0.69323 | valid_gini: 0.65455 |  0:00:14s
# epoch 44 | loss: 0.33722 | train_gini: 0.77056 | valid_gini: 0.7037  |  0:00:14s
# epoch 45 | loss: 0.29405 | train_gini: 0.74699 | valid_gini: 0.68966 |  0:00:15s
# epoch 46 | loss: 0.3351  | train_gini: 0.77922 | valid_gini: 0.7037  |  0:00:15s
# epoch 47 | loss: 0.32758 | train_gini: 0.78481 | valid_gini: 0.71698 |  0:00:15s
# epoch 48 | loss: 0.32882 | train_gini: 0.77178 | valid_gini: 0.71186 |  0:00:15s
# epoch 49 | loss: 0.29837 | train_gini: 0.72441 | valid_gini: 0.70175 |  0:00:16s
# epoch 50 | loss: 0.29716 | train_gini: 0.73359 | valid_gini: 0.67857 |  0:00:16s
# epoch 51 | loss: 0.31373 | train_gini: 0.75102 | valid_gini: 0.69388 |  0:00:16s
# epoch 52 | loss: 0.29995 | train_gini: 0.76724 | valid_gini: 0.68    |  0:00:17s
# epoch 53 | loss: 0.32005 | train_gini: 0.82243 | valid_gini: 0.66667 |  0:00:17s
# epoch 54 | loss: 0.27971 | train_gini: 0.78846 | valid_gini: 0.69565 |  0:00:17s
# epoch 55 | loss: 0.24396 | train_gini: 0.80189 | valid_gini: 0.73469 |  0:00:18s
# epoch 56 | loss: 0.25947 | train_gini: 0.80349 | valid_gini: 0.71698 |  0:00:18s
# epoch 57 | loss: 0.28121 | train_gini: 0.80672 | valid_gini: 0.7037  |  0:00:18s
# epoch 58 | loss: 0.26467 | train_gini: 0.8785  | valid_gini: 0.69565 |  0:00:19s
# epoch 59 | loss: 0.25908 | train_gini: 0.85981 | valid_gini: 0.625   |  0:00:19s
# epoch 60 | loss: 0.21622 | train_gini: 0.8     | valid_gini: 0.65455 |  0:00:19s
# epoch 61 | loss: 0.29691 | train_gini: 0.82819 | valid_gini: 0.67925 |  0:00:20s
# epoch 62 | loss: 0.23248 | train_gini: 0.82609 | valid_gini: 0.69091 |  0:00:20s
# epoch 63 | loss: 0.22056 | train_gini: 0.83929 | valid_gini: 0.72    |  0:00:20s
# epoch 64 | loss: 0.32713 | train_gini: 0.85714 | valid_gini: 0.76923 |  0:00:21s
# epoch 65 | loss: 0.23563 | train_gini: 0.81739 | valid_gini: 0.69091 |  0:00:21s
# epoch 66 | loss: 0.28159 | train_gini: 0.86607 | valid_gini: 0.67857 |  0:00:21s
# epoch 67 | loss: 0.21306 | train_gini: 0.8785  | valid_gini: 0.74074 |  0:00:22s
# epoch 68 | loss: 0.27599 | train_gini: 0.88889 | valid_gini: 0.73077 |  0:00:22s
# epoch 69 | loss: 0.24268 | train_gini: 0.89855 | valid_gini: 0.66667 |  0:00:22s
# epoch 70 | loss: 0.26388 | train_gini: 0.85973 | valid_gini: 0.68966 |  0:00:23s
# epoch 71 | loss: 0.24448 | train_gini: 0.83478 | valid_gini: 0.7     |  0:00:23s
# epoch 72 | loss: 0.20611 | train_gini: 0.86222 | valid_gini: 0.73077 |  0:00:23s
# epoch 73 | loss: 0.19434 | train_gini: 0.8932  | valid_gini: 0.73469 |  0:00:24s
# epoch 74 | loss: 0.2704  | train_gini: 0.94059 | valid_gini: 0.69231 |  0:00:24s
# epoch 75 | loss: 0.191   | train_gini: 0.88785 | valid_gini: 0.69091 |  0:00:24s
# epoch 76 | loss: 0.24044 | train_gini: 0.88889 | valid_gini: 0.71429 |  0:00:25s
# epoch 77 | loss: 0.17801 | train_gini: 0.87719 | valid_gini: 0.69091 |  0:00:25s
# epoch 78 | loss: 0.2037  | train_gini: 0.83333 | valid_gini: 0.66667 |  0:00:25s
# epoch 79 | loss: 0.16283 | train_gini: 0.85345 | valid_gini: 0.67857 |  0:00:26s
# epoch 80 | loss: 0.23363 | train_gini: 0.91176 | valid_gini: 0.65385 |  0:00:26s
# epoch 81 | loss: 0.20512 | train_gini: 0.88288 | valid_gini: 0.67925 |  0:00:26s
# epoch 82 | loss: 0.19551 | train_gini: 0.86344 | valid_gini: 0.7037  |  0:00:27s
# epoch 83 | loss: 0.17009 | train_gini: 0.89091 | valid_gini: 0.7037  |  0:00:27s
# epoch 84 | loss: 0.22484 | train_gini: 0.9009  | valid_gini: 0.69091 |  0:00:27s
# epoch 85 | loss: 0.17308 | train_gini: 0.91589 | valid_gini: 0.67925 |  0:00:28s
# epoch 86 | loss: 0.21104 | train_gini: 0.91667 | valid_gini: 0.67925 |  0:00:28s
# epoch 87 | loss: 0.19371 | train_gini: 0.89498 | valid_gini: 0.61538 |  0:00:28s
# epoch 88 | loss: 0.20656 | train_gini: 0.89815 | valid_gini: 0.58824 |  0:00:29s
# epoch 89 | loss: 0.17862 | train_gini: 0.89686 | valid_gini: 0.61818 |  0:00:29s
# epoch 90 | loss: 0.16735 | train_gini: 0.84483 | valid_gini: 0.65517 |  0:00:29s
# epoch 91 | loss: 0.19839 | train_gini: 0.89815 | valid_gini: 0.67925 |  0:00:30s
# epoch 92 | loss: 0.14367 | train_gini: 0.94527 | valid_gini: 0.69231 |  0:00:30s
# epoch 93 | loss: 0.15287 | train_gini: 0.93839 | valid_gini: 0.67925 |  0:00:30s
# epoch 94 | loss: 0.19713 | train_gini: 0.94286 | valid_gini: 0.65306 |  0:00:30s
# epoch 95 | loss: 0.13302 | train_gini: 0.94472 | valid_gini: 0.59091 |  0:00:31s
# epoch 96 | loss: 0.13719 | train_gini: 0.93396 | valid_gini: 0.65217 |  0:00:31s
# epoch 97 | loss: 0.11374 | train_gini: 0.91244 | valid_gini: 0.6383  |  0:00:31s
# epoch 98 | loss: 0.17055 | train_gini: 0.92237 | valid_gini: 0.69388 |  0:00:32s
# epoch 99 | loss: 0.12864 | train_gini: 0.9108  | valid_gini: 0.70588 |  0:00:32s
# epoch 100| loss: 0.12279 | train_gini: 0.93897 | valid_gini: 0.68    |  0:00:32s
# epoch 101| loss: 0.10834 | train_gini: 0.93897 | valid_gini: 0.6383  |  0:00:32s
# epoch 102| loss: 0.11129 | train_gini: 0.97087 | valid_gini: 0.6383  |  0:00:33s
# epoch 103| loss: 0.14143 | train_gini: 0.97537 | valid_gini: 0.68    |  0:00:33s
# epoch 104| loss: 0.13856 | train_gini: 0.94393 | valid_gini: 0.68    |  0:00:33s
# epoch 105| loss: 0.13863 | train_gini: 0.88889 | valid_gini: 0.60714 |  0:00:34s
# epoch 106| loss: 0.13    | train_gini: 0.92523 | valid_gini: 0.61818 |  0:00:34s
# epoch 107| loss: 0.10892 | train_gini: 0.9434  | valid_gini: 0.62963 |  0:00:34s
# epoch 108| loss: 0.10253 | train_gini: 0.95735 | valid_gini: 0.64    |  0:00:35s
# epoch 109| loss: 0.1096  | train_gini: 0.9619  | valid_gini: 0.65306 |  0:00:35s
# epoch 110| loss: 0.13305 | train_gini: 0.97585 | valid_gini: 0.69388 |  0:00:35s
# epoch 111| loss: 0.16346 | train_gini: 0.93023 | valid_gini: 0.61224 |  0:00:35s
# epoch 112| loss: 0.16681 | train_gini: 0.9378  | valid_gini: 0.65217 |  0:00:36s
# epoch 113| loss: 0.16291 | train_gini: 0.92019 | valid_gini: 0.69231 |  0:00:36s
# epoch 114| loss: 0.16334 | train_gini: 0.91743 | valid_gini: 0.71698 |  0:00:36s
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_valid_gini = 0.76923
#               precision    recall  f1-score   support
#
#          bad       0.78      0.90      0.84        31
#         good       0.97      0.92      0.94       100
#
#     accuracy                           0.92       131
#    macro avg       0.87      0.91      0.89       131
# weighted avg       0.92      0.92      0.92       131
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.95442 | train_gini: 0.36676 | valid_gini: 0.43678 |  0:00:00s
# epoch 1  | loss: 0.7751  | train_gini: 0.4532  | valid_gini: 0.48    |  0:00:00s
# epoch 2  | loss: 0.71186 | train_gini: 0.26154 | valid_gini: 0.3125  |  0:00:00s
# epoch 3  | loss: 0.70432 | train_gini: 0.34783 | valid_gini: 0.44444 |  0:00:01s
# epoch 4  | loss: 0.65346 | train_gini: 0.47953 | valid_gini: 0.51064 |  0:00:01s
# epoch 5  | loss: 0.68016 | train_gini: 0.4023  | valid_gini: 0.39024 |  0:00:01s
# epoch 6  | loss: 0.62412 | train_gini: 0.44444 | valid_gini: 0.44444 |  0:00:02s
# epoch 7  | loss: 0.6652  | train_gini: 0.52294 | valid_gini: 0.54545 |  0:00:02s
# epoch 8  | loss: 0.63227 | train_gini: 0.47872 | valid_gini: 0.49057 |  0:00:02s
# epoch 9  | loss: 0.60806 | train_gini: 0.43312 | valid_gini: 0.55    |  0:00:02s
# epoch 10 | loss: 0.60841 | train_gini: 0.55    | valid_gini: 0.62745 |  0:00:03s
# epoch 11 | loss: 0.56944 | train_gini: 0.57459 | valid_gini: 0.63636 |  0:00:03s
# epoch 12 | loss: 0.61553 | train_gini: 0.55959 | valid_gini: 0.59574 |  0:00:03s
# epoch 13 | loss: 0.60752 | train_gini: 0.61187 | valid_gini: 0.57143 |  0:00:04s
# epoch 14 | loss: 0.60629 | train_gini: 0.57273 | valid_gini: 0.60377 |  0:00:04s
# epoch 15 | loss: 0.59407 | train_gini: 0.5679  | valid_gini: 0.57627 |  0:00:04s
# epoch 16 | loss: 0.55282 | train_gini: 0.50735 | valid_gini: 0.5     |  0:00:05s
# epoch 17 | loss: 0.62344 | train_gini: 0.54545 | valid_gini: 0.51852 |  0:00:05s
# epoch 18 | loss: 0.55887 | train_gini: 0.52632 | valid_gini: 0.52    |  0:00:05s
# epoch 19 | loss: 0.56228 | train_gini: 0.54321 | valid_gini: 0.53846 |  0:00:06s
# epoch 20 | loss: 0.6195  | train_gini: 0.54545 | valid_gini: 0.46875 |  0:00:06s
# epoch 21 | loss: 0.55575 | train_gini: 0.56537 | valid_gini: 0.5625  |  0:00:06s
# epoch 22 | loss: 0.59082 | train_gini: 0.64198 | valid_gini: 0.59259 |  0:00:07s
# epoch 23 | loss: 0.58421 | train_gini: 0.65517 | valid_gini: 0.60377 |  0:00:07s
# epoch 24 | loss: 0.57558 | train_gini: 0.54286 | valid_gini: 0.61224 |  0:00:07s
# epoch 25 | loss: 0.51923 | train_gini: 0.56    | valid_gini: 0.53333 |  0:00:07s
# epoch 26 | loss: 0.56533 | train_gini: 0.60444 | valid_gini: 0.55319 |  0:00:08s
# epoch 27 | loss: 0.52981 | train_gini: 0.59322 | valid_gini: 0.51852 |  0:00:08s
# epoch 28 | loss: 0.53617 | train_gini: 0.60581 | valid_gini: 0.53846 |  0:00:08s
# epoch 29 | loss: 0.53778 | train_gini: 0.59649 | valid_gini: 0.61224 |  0:00:09s
# epoch 30 | loss: 0.46496 | train_gini: 0.64706 | valid_gini: 0.58333 |  0:00:09s
# epoch 31 | loss: 0.4455  | train_gini: 0.67811 | valid_gini: 0.57692 |  0:00:09s
# epoch 32 | loss: 0.4911  | train_gini: 0.68826 | valid_gini: 0.6     |  0:00:10s
# epoch 33 | loss: 0.49677 | train_gini: 0.68908 | valid_gini: 0.56    |  0:00:10s
# epoch 34 | loss: 0.51478 | train_gini: 0.65833 | valid_gini: 0.54902 |  0:00:10s
# epoch 35 | loss: 0.53093 | train_gini: 0.65728 | valid_gini: 0.57778 |  0:00:11s
# epoch 36 | loss: 0.45508 | train_gini: 0.68526 | valid_gini: 0.64407 |  0:00:11s
# epoch 37 | loss: 0.50763 | train_gini: 0.6789  | valid_gini: 0.64    |  0:00:11s
# epoch 38 | loss: 0.50953 | train_gini: 0.64435 | valid_gini: 0.66667 |  0:00:11s
# epoch 39 | loss: 0.51168 | train_gini: 0.64957 | valid_gini: 0.56    |  0:00:12s
# epoch 40 | loss: 0.43682 | train_gini: 0.61538 | valid_gini: 0.66667 |  0:00:12s
# epoch 41 | loss: 0.45625 | train_gini: 0.62097 | valid_gini: 0.61818 |  0:00:12s
# epoch 42 | loss: 0.46518 | train_gini: 0.616   | valid_gini: 0.62963 |  0:00:13s
# epoch 43 | loss: 0.44486 | train_gini: 0.62642 | valid_gini: 0.64286 |  0:00:13s
# epoch 44 | loss: 0.4717  | train_gini: 0.66667 | valid_gini: 0.69565 |  0:00:13s
# epoch 45 | loss: 0.45936 | train_gini: 0.71749 | valid_gini: 0.66667 |  0:00:14s
# epoch 46 | loss: 0.42132 | train_gini: 0.68041 | valid_gini: 0.65116 |  0:00:14s
# epoch 47 | loss: 0.44292 | train_gini: 0.66337 | valid_gini: 0.68085 |  0:00:14s
# epoch 48 | loss: 0.3933  | train_gini: 0.67358 | valid_gini: 0.68085 |  0:00:14s
# epoch 49 | loss: 0.43837 | train_gini: 0.6888  | valid_gini: 0.57143 |  0:00:15s
# epoch 50 | loss: 0.45429 | train_gini: 0.64964 | valid_gini: 0.59375 |  0:00:15s
# epoch 51 | loss: 0.39215 | train_gini: 0.72321 | valid_gini: 0.66667 |  0:00:15s
# epoch 52 | loss: 0.45522 | train_gini: 0.73892 | valid_gini: 0.75556 |  0:00:16s
# epoch 53 | loss: 0.43277 | train_gini: 0.688   | valid_gini: 0.58065 |  0:00:16s
# epoch 54 | loss: 0.4185  | train_gini: 0.64979 | valid_gini: 0.56604 |  0:00:16s
# epoch 55 | loss: 0.40689 | train_gini: 0.65728 | valid_gini: 0.8     |  0:00:17s
# epoch 56 | loss: 0.36368 | train_gini: 0.65854 | valid_gini: 0.71698 |  0:00:17s
# epoch 57 | loss: 0.42361 | train_gini: 0.6556  | valid_gini: 0.72    |  0:00:17s
# epoch 58 | loss: 0.44587 | train_gini: 0.69333 | valid_gini: 0.75    |  0:00:18s
# epoch 59 | loss: 0.39295 | train_gini: 0.69869 | valid_gini: 0.75    |  0:00:18s
# epoch 60 | loss: 0.35282 | train_gini: 0.696   | valid_gini: 0.75862 |  0:00:19s
# epoch 61 | loss: 0.38403 | train_gini: 0.66122 | valid_gini: 0.69091 |  0:00:19s
# epoch 62 | loss: 0.45457 | train_gini: 0.69231 | valid_gini: 0.69388 |  0:00:19s
# epoch 63 | loss: 0.39053 | train_gini: 0.71028 | valid_gini: 0.65306 |  0:00:20s
# epoch 64 | loss: 0.39527 | train_gini: 0.72034 | valid_gini: 0.62295 |  0:00:20s
# epoch 65 | loss: 0.35904 | train_gini: 0.75113 | valid_gini: 0.61538 |  0:00:21s
# epoch 66 | loss: 0.40269 | train_gini: 0.76786 | valid_gini: 0.62963 |  0:00:21s
# epoch 67 | loss: 0.34513 | train_gini: 0.73092 | valid_gini: 0.68966 |  0:00:21s
# epoch 68 | loss: 0.3653  | train_gini: 0.7438  | valid_gini: 0.71429 |  0:00:22s
# epoch 69 | loss: 0.33412 | train_gini: 0.80189 | valid_gini: 0.73469 |  0:00:22s
# epoch 70 | loss: 0.29806 | train_gini: 0.79803 | valid_gini: 0.74419 |  0:00:22s
# epoch 71 | loss: 0.32117 | train_gini: 0.7489  | valid_gini: 0.76    |  0:00:23s
# epoch 72 | loss: 0.33593 | train_gini: 0.72289 | valid_gini: 0.71698 |  0:00:23s
# epoch 73 | loss: 0.34838 | train_gini: 0.78222 | valid_gini: 0.67925 |  0:00:23s
# epoch 74 | loss: 0.36297 | train_gini: 0.80788 | valid_gini: 0.72    |  0:00:24s
# epoch 75 | loss: 0.2864  | train_gini: 0.80176 | valid_gini: 0.69091 |  0:00:24s
# epoch 76 | loss: 0.3435  | train_gini: 0.79638 | valid_gini: 0.71698 |  0:00:24s
# epoch 77 | loss: 0.28283 | train_gini: 0.7913  | valid_gini: 0.7037  |  0:00:25s
# epoch 78 | loss: 0.35892 | train_gini: 0.78947 | valid_gini: 0.66667 |  0:00:25s
# epoch 79 | loss: 0.28298 | train_gini: 0.77686 | valid_gini: 0.51852 |  0:00:25s
# epoch 80 | loss: 0.28146 | train_gini: 0.77119 | valid_gini: 0.44    |  0:00:26s
# epoch 81 | loss: 0.32641 | train_gini: 0.76995 | valid_gini: 0.56522 |  0:00:26s
# epoch 82 | loss: 0.34799 | train_gini: 0.80569 | valid_gini: 0.7234  |  0:00:26s
# epoch 83 | loss: 0.25597 | train_gini: 0.81416 | valid_gini: 0.73077 |  0:00:27s
# epoch 84 | loss: 0.34586 | train_gini: 0.80531 | valid_gini: 0.69231 |  0:00:27s
# epoch 85 | loss: 0.3422  | train_gini: 0.85714 | valid_gini: 0.78261 |  0:00:27s
# epoch 86 | loss: 0.34002 | train_gini: 0.82857 | valid_gini: 0.80851 |  0:00:28s
# epoch 87 | loss: 0.28809 | train_gini: 0.79817 | valid_gini: 0.76    |  0:00:28s
# epoch 88 | loss: 0.2506  | train_gini: 0.78414 | valid_gini: 0.71698 |  0:00:28s
# epoch 89 | loss: 0.31737 | train_gini: 0.82096 | valid_gini: 0.69091 |  0:00:29s
# epoch 90 | loss: 0.28785 | train_gini: 0.81385 | valid_gini: 0.7037  |  0:00:29s
# epoch 91 | loss: 0.21779 | train_gini: 0.82569 | valid_gini: 0.76    |  0:00:29s
# epoch 92 | loss: 0.27646 | train_gini: 0.84932 | valid_gini: 0.7451  |  0:00:30s
# epoch 93 | loss: 0.25326 | train_gini: 0.87081 | valid_gini: 0.80851 |  0:00:30s
# epoch 94 | loss: 0.20633 | train_gini: 0.83568 | valid_gini: 0.77551 |  0:00:31s
# epoch 95 | loss: 0.34231 | train_gini: 0.82192 | valid_gini: 0.71698 |  0:00:31s
# epoch 96 | loss: 0.29676 | train_gini: 0.82883 | valid_gini: 0.69091 |  0:00:31s
# epoch 97 | loss: 0.283   | train_gini: 0.81982 | valid_gini: 0.71698 |  0:00:32s
# epoch 98 | loss: 0.34688 | train_gini: 0.85455 | valid_gini: 0.71698 |  0:00:32s
# epoch 99 | loss: 0.25954 | train_gini: 0.83486 | valid_gini: 0.76    |  0:00:32s
# epoch 100| loss: 0.29096 | train_gini: 0.85321 | valid_gini: 0.75    |  0:00:33s
# epoch 101| loss: 0.27118 | train_gini: 0.85849 | valid_gini: 0.76596 |  0:00:33s
# epoch 102| loss: 0.28194 | train_gini: 0.83258 | valid_gini: 0.75    |  0:00:33s
# epoch 103| loss: 0.26172 | train_gini: 0.84716 | valid_gini: 0.72    |  0:00:33s
# epoch 104| loss: 0.16532 | train_gini: 0.86087 | valid_gini: 0.67857 |  0:00:34s
# epoch 105| loss: 0.23951 | train_gini: 0.85345 | valid_gini: 0.7037  |  0:00:34s
# epoch 106| loss: 0.23821 | train_gini: 0.87558 | valid_gini: 0.75    |  0:00:34s
# epoch 107| loss: 0.26733 | train_gini: 0.84821 | valid_gini: 0.7451  |  0:00:35s
# epoch 108| loss: 0.1997  | train_gini: 0.86878 | valid_gini: 0.77551 |  0:00:35s
# epoch 109| loss: 0.31861 | train_gini: 0.89756 | valid_gini: 0.76596 |  0:00:36s
# epoch 110| loss: 0.23678 | train_gini: 0.86512 | valid_gini: 0.72    |  0:00:36s
# epoch 111| loss: 0.15964 | train_gini: 0.85217 | valid_gini: 0.67925 |  0:00:36s
# epoch 112| loss: 0.18748 | train_gini: 0.86222 | valid_gini: 0.72    |  0:00:37s
# epoch 113| loss: 0.20276 | train_gini: 0.89952 | valid_gini: 0.73469 |  0:00:37s
# epoch 114| loss: 0.21073 | train_gini: 0.88679 | valid_gini: 0.76596 |  0:00:37s
# epoch 115| loss: 0.26506 | train_gini: 0.85345 | valid_gini: 0.72    |  0:00:38s
# epoch 116| loss: 0.19428 | train_gini: 0.89091 | valid_gini: 0.72    |  0:00:38s
# epoch 117| loss: 0.16486 | train_gini: 0.91429 | valid_gini: 0.73469 |  0:00:38s
# epoch 118| loss: 0.20688 | train_gini: 0.90233 | valid_gini: 0.72    |  0:00:39s
# epoch 119| loss: 0.19097 | train_gini: 0.84615 | valid_gini: 0.64286 |  0:00:39s
# epoch 120| loss: 0.35668 | train_gini: 0.86842 | valid_gini: 0.70588 |  0:00:39s
# epoch 121| loss: 0.24462 | train_gini: 0.84018 | valid_gini: 0.72    |  0:00:40s
# epoch 122| loss: 0.26669 | train_gini: 0.88073 | valid_gini: 0.72    |  0:00:40s
# epoch 123| loss: 0.22442 | train_gini: 0.85586 | valid_gini: 0.72    |  0:00:40s
# epoch 124| loss: 0.23908 | train_gini: 0.88152 | valid_gini: 0.7234  |  0:00:41s
# epoch 125| loss: 0.26255 | train_gini: 0.91346 | valid_gini: 0.73913 |  0:00:41s
# epoch 126| loss: 0.21424 | train_gini: 0.90233 | valid_gini: 0.73077 |  0:00:41s
# epoch 127| loss: 0.18995 | train_gini: 0.875   | valid_gini: 0.7451  |  0:00:42s
# epoch 128| loss: 0.19967 | train_gini: 0.91943 | valid_gini: 0.70588 |  0:00:42s
# epoch 129| loss: 0.22338 | train_gini: 0.92823 | valid_gini: 0.69388 |  0:00:42s
# epoch 130| loss: 0.16615 | train_gini: 0.88372 | valid_gini: 0.67925 |  0:00:43s
# epoch 131| loss: 0.14009 | train_gini: 0.87611 | valid_gini: 0.67857 |  0:00:43s
# epoch 132| loss: 0.21415 | train_gini: 0.9     | valid_gini: 0.71698 |  0:00:44s
# epoch 133| loss: 0.14941 | train_gini: 0.91743 | valid_gini: 0.67857 |  0:00:44s
# epoch 134| loss: 0.18145 | train_gini: 0.90909 | valid_gini: 0.67857 |  0:00:44s
# epoch 135| loss: 0.17678 | train_gini: 0.89686 | valid_gini: 0.66667 |  0:00:44s
# epoch 136| loss: 0.15573 | train_gini: 0.92093 | valid_gini: 0.77551 |  0:00:45s
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_valid_gini = 0.80851
#               precision    recall  f1-score   support
#
#          bad       0.72      0.81      0.76        32
#         good       0.94      0.90      0.92        99
#
#     accuracy                           0.88       131
#    macro avg       0.83      0.86      0.84       131
# weighted avg       0.88      0.88      0.88       131
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.87881 | train_gini: 0.32292 | valid_gini: 0.31915 |  0:00:00s
# epoch 1  | loss: 0.80132 | train_gini: 0.37736 | valid_gini: 0.37931 |  0:00:00s
# epoch 2  | loss: 0.70451 | train_gini: 0.40506 | valid_gini: 0.4878  |  0:00:01s
# epoch 3  | loss: 0.65169 | train_gini: 0.45455 | valid_gini: 0.34286 |  0:00:01s
# epoch 4  | loss: 0.67724 | train_gini: 0.48454 | valid_gini: 0.52174 |  0:00:01s
# epoch 5  | loss: 0.66114 | train_gini: 0.42177 | valid_gini: 0.48649 |  0:00:02s
# epoch 6  | loss: 0.61627 | train_gini: 0.45205 | valid_gini: 0.42105 |  0:00:02s
# epoch 7  | loss: 0.64676 | train_gini: 0.5509  | valid_gini: 0.52381 |  0:00:02s
# epoch 8  | loss: 0.64661 | train_gini: 0.61836 | valid_gini: 0.6     |  0:00:03s
# epoch 9  | loss: 0.6189  | train_gini: 0.5935  | valid_gini: 0.63333 |  0:00:03s
# epoch 10 | loss: 0.56397 | train_gini: 0.55172 | valid_gini: 0.64706 |  0:00:03s
# epoch 11 | loss: 0.58842 | train_gini: 0.52817 | valid_gini: 0.52778 |  0:00:04s
# epoch 12 | loss: 0.60856 | train_gini: 0.55516 | valid_gini: 0.51948 |  0:00:04s
# epoch 13 | loss: 0.65052 | train_gini: 0.52402 | valid_gini: 0.58065 |  0:00:04s
# epoch 14 | loss: 0.59461 | train_gini: 0.5298  | valid_gini: 0.5641  |  0:00:05s
# epoch 15 | loss: 0.60552 | train_gini: 0.55172 | valid_gini: 0.63333 |  0:00:05s
# epoch 16 | loss: 0.54996 | train_gini: 0.59716 | valid_gini: 0.55556 |  0:00:05s
# epoch 17 | loss: 0.53026 | train_gini: 0.5812  | valid_gini: 0.53333 |  0:00:06s
# epoch 18 | loss: 0.58728 | train_gini: 0.625   | valid_gini: 0.63768 |  0:00:06s
# epoch 19 | loss: 0.5447  | train_gini: 0.61616 | valid_gini: 0.66667 |  0:00:06s
# epoch 20 | loss: 0.58922 | train_gini: 0.61468 | valid_gini: 0.61538 |  0:00:07s
# epoch 21 | loss: 0.54335 | train_gini: 0.57843 | valid_gini: 0.58824 |  0:00:07s
# epoch 22 | loss: 0.56445 | train_gini: 0.63874 | valid_gini: 0.64    |  0:00:07s
# epoch 23 | loss: 0.50473 | train_gini: 0.62241 | valid_gini: 0.49057 |  0:00:07s
# epoch 24 | loss: 0.52045 | train_gini: 0.65385 | valid_gini: 0.57692 |  0:00:08s
# epoch 25 | loss: 0.51158 | train_gini: 0.62097 | valid_gini: 0.5     |  0:00:08s
# epoch 26 | loss: 0.51242 | train_gini: 0.61789 | valid_gini: 0.5     |  0:00:08s
# epoch 27 | loss: 0.53155 | train_gini: 0.61355 | valid_gini: 0.53333 |  0:00:09s
# epoch 28 | loss: 0.47843 | train_gini: 0.62992 | valid_gini: 0.55172 |  0:00:09s
# epoch 29 | loss: 0.49063 | train_gini: 0.65094 | valid_gini: 0.66667 |  0:00:09s
# epoch 30 | loss: 0.48502 | train_gini: 0.65366 | valid_gini: 0.68085 |  0:00:10s
# epoch 31 | loss: 0.47477 | train_gini: 0.63478 | valid_gini: 0.58182 |  0:00:10s
# epoch 32 | loss: 0.46577 | train_gini: 0.65487 | valid_gini: 0.56604 |  0:00:10s
# epoch 33 | loss: 0.47205 | train_gini: 0.69231 | valid_gini: 0.6087  |  0:00:11s
# epoch 34 | loss: 0.44749 | train_gini: 0.67925 | valid_gini: 0.625   |  0:00:11s
# epoch 35 | loss: 0.46092 | train_gini: 0.66351 | valid_gini: 0.66667 |  0:00:11s
# epoch 36 | loss: 0.45865 | train_gini: 0.66383 | valid_gini: 0.66667 |  0:00:12s
# epoch 37 | loss: 0.4594  | train_gini: 0.64957 | valid_gini: 0.61017 |  0:00:12s
# epoch 38 | loss: 0.43341 | train_gini: 0.66667 | valid_gini: 0.57143 |  0:00:12s
# epoch 39 | loss: 0.4152  | train_gini: 0.69484 | valid_gini: 0.68    |  0:00:13s
# epoch 40 | loss: 0.44258 | train_gini: 0.71287 | valid_gini: 0.57778 |  0:00:13s
# epoch 41 | loss: 0.39106 | train_gini: 0.73913 | valid_gini: 0.62222 |  0:00:13s
# epoch 42 | loss: 0.42983 | train_gini: 0.69091 | valid_gini: 0.55556 |  0:00:14s
# epoch 43 | loss: 0.40015 | train_gini: 0.68182 | valid_gini: 0.51852 |  0:00:14s
# epoch 44 | loss: 0.38042 | train_gini: 0.75824 | valid_gini: 0.6     |  0:00:14s
# epoch 45 | loss: 0.44777 | train_gini: 0.73892 | valid_gini: 0.59091 |  0:00:15s
# epoch 46 | loss: 0.42376 | train_gini: 0.76    | valid_gini: 0.65306 |  0:00:15s
# epoch 47 | loss: 0.4422  | train_gini: 0.71552 | valid_gini: 0.64286 |  0:00:15s
# epoch 48 | loss: 0.41705 | train_gini: 0.74396 | valid_gini: 0.7234  |  0:00:16s
# epoch 49 | loss: 0.36394 | train_gini: 0.72    | valid_gini: 0.69388 |  0:00:16s
# epoch 50 | loss: 0.33728 | train_gini: 0.73973 | valid_gini: 0.69231 |  0:00:16s
# epoch 51 | loss: 0.41738 | train_gini: 0.75    | valid_gini: 0.69388 |  0:00:17s
# epoch 52 | loss: 0.36864 | train_gini: 0.75269 | valid_gini: 0.68182 |  0:00:17s
# epoch 53 | loss: 0.38295 | train_gini: 0.7767  | valid_gini: 0.73469 |  0:00:17s
# epoch 54 | loss: 0.39666 | train_gini: 0.73864 | valid_gini: 0.63636 |  0:00:18s
# epoch 55 | loss: 0.41774 | train_gini: 0.72414 | valid_gini: 0.62222 |  0:00:18s
# epoch 56 | loss: 0.35891 | train_gini: 0.75    | valid_gini: 0.7037  |  0:00:18s
# epoch 57 | loss: 0.35882 | train_gini: 0.77612 | valid_gini: 0.70833 |  0:00:19s
# epoch 58 | loss: 0.3604  | train_gini: 0.76136 | valid_gini: 0.68085 |  0:00:19s
# epoch 59 | loss: 0.34925 | train_gini: 0.79602 | valid_gini: 0.69231 |  0:00:19s
# epoch 60 | loss: 0.34238 | train_gini: 0.78846 | valid_gini: 0.71429 |  0:00:19s
# epoch 61 | loss: 0.30386 | train_gini: 0.77073 | valid_gini: 0.69231 |  0:00:20s
# epoch 62 | loss: 0.29707 | train_gini: 0.78173 | valid_gini: 0.69565 |  0:00:20s
# epoch 63 | loss: 0.31612 | train_gini: 0.81407 | valid_gini: 0.68085 |  0:00:20s
# epoch 64 | loss: 0.32594 | train_gini: 0.80184 | valid_gini: 0.76923 |  0:00:21s
# epoch 65 | loss: 0.30094 | train_gini: 0.77982 | valid_gini: 0.75472 |  0:00:21s
# epoch 66 | loss: 0.27199 | train_gini: 0.78761 | valid_gini: 0.69091 |  0:00:21s
# epoch 67 | loss: 0.27206 | train_gini: 0.7907  | valid_gini: 0.70175 |  0:00:22s
# epoch 68 | loss: 0.31491 | train_gini: 0.82653 | valid_gini: 0.69388 |  0:00:22s
# epoch 69 | loss: 0.24052 | train_gini: 0.81407 | valid_gini: 0.75    |  0:00:22s
# epoch 70 | loss: 0.2962  | train_gini: 0.84507 | valid_gini: 0.76923 |  0:00:22s
# epoch 71 | loss: 0.2474  | train_gini: 0.8     | valid_gini: 0.72727 |  0:00:23s
# epoch 72 | loss: 0.28715 | train_gini: 0.82456 | valid_gini: 0.74074 |  0:00:23s
# epoch 73 | loss: 0.26781 | train_gini: 0.84259 | valid_gini: 0.70833 |  0:00:23s
# epoch 74 | loss: 0.28785 | train_gini: 0.84058 | valid_gini: 0.625   |  0:00:24s
# epoch 75 | loss: 0.25277 | train_gini: 0.83019 | valid_gini: 0.69231 |  0:00:24s
# epoch 76 | loss: 0.27748 | train_gini: 0.82511 | valid_gini: 0.74074 |  0:00:24s
# epoch 77 | loss: 0.23639 | train_gini: 0.82143 | valid_gini: 0.64151 |  0:00:25s
# epoch 78 | loss: 0.27125 | train_gini: 0.83178 | valid_gini: 0.65385 |  0:00:25s
# epoch 79 | loss: 0.26655 | train_gini: 0.78603 | valid_gini: 0.65455 |  0:00:25s
# epoch 80 | loss: 0.25937 | train_gini: 0.79638 | valid_gini: 0.64    |  0:00:26s
# epoch 81 | loss: 0.25159 | train_gini: 0.83654 | valid_gini: 0.66667 |  0:00:26s
# epoch 82 | loss: 0.28767 | train_gini: 0.85577 | valid_gini: 0.61224 |  0:00:26s
# epoch 83 | loss: 0.28063 | train_gini: 0.82667 | valid_gini: 0.64286 |  0:00:27s
# epoch 84 | loss: 0.25059 | train_gini: 0.85581 | valid_gini: 0.66667 |  0:00:27s
# epoch 85 | loss: 0.27509 | train_gini: 0.85149 | valid_gini: 0.59574 |  0:00:27s
# epoch 86 | loss: 0.20793 | train_gini: 0.85714 | valid_gini: 0.66667 |  0:00:28s
# epoch 87 | loss: 0.22231 | train_gini: 0.85455 | valid_gini: 0.61818 |  0:00:28s
# epoch 88 | loss: 0.2209  | train_gini: 0.86636 | valid_gini: 0.62963 |  0:00:28s
# epoch 89 | loss: 0.2217  | train_gini: 0.837   | valid_gini: 0.61017 |  0:00:29s
# epoch 90 | loss: 0.26231 | train_gini: 0.85068 | valid_gini: 0.61818 |  0:00:29s
# epoch 91 | loss: 0.19866 | train_gini: 0.87204 | valid_gini: 0.65306 |  0:00:29s
# epoch 92 | loss: 0.21238 | train_gini: 0.83556 | valid_gini: 0.62745 |  0:00:30s
# epoch 93 | loss: 0.22224 | train_gini: 0.85463 | valid_gini: 0.64151 |  0:00:30s
# epoch 94 | loss: 0.21388 | train_gini: 0.8835  | valid_gini: 0.65217 |  0:00:31s
# epoch 95 | loss: 0.19951 | train_gini: 0.89202 | valid_gini: 0.59574 |  0:00:31s
# epoch 96 | loss: 0.21815 | train_gini: 0.85714 | valid_gini: 0.62963 |  0:00:31s
# epoch 97 | loss: 0.18163 | train_gini: 0.83193 | valid_gini: 0.60377 |  0:00:32s
# epoch 98 | loss: 0.20438 | train_gini: 0.86364 | valid_gini: 0.65306 |  0:00:32s
# epoch 99 | loss: 0.18271 | train_gini: 0.85333 | valid_gini: 0.66667 |  0:00:32s
# epoch 100| loss: 0.20333 | train_gini: 0.78543 | valid_gini: 0.59649 |  0:00:33s
# epoch 101| loss: 0.20926 | train_gini: 0.86239 | valid_gini: 0.62745 |  0:00:33s
# epoch 102| loss: 0.2426  | train_gini: 0.90291 | valid_gini: 0.625   |  0:00:33s
# epoch 103| loss: 0.16498 | train_gini: 0.90291 | valid_gini: 0.66667 |  0:00:34s
# epoch 104| loss: 0.19849 | train_gini: 0.86607 | valid_gini: 0.66667 |  0:00:34s
# epoch 105| loss: 0.15079 | train_gini: 0.89498 | valid_gini: 0.68085 |  0:00:34s
# epoch 106| loss: 0.16812 | train_gini: 0.88119 | valid_gini: 0.65217 |  0:00:35s
# epoch 107| loss: 0.23703 | train_gini: 0.89899 | valid_gini: 0.66667 |  0:00:35s
# epoch 108| loss: 0.19548 | train_gini: 0.88889 | valid_gini: 0.6087  |  0:00:35s
# epoch 109| loss: 0.17554 | train_gini: 0.90654 | valid_gini: 0.54545 |  0:00:36s
# epoch 110| loss: 0.18774 | train_gini: 0.8972  | valid_gini: 0.54167 |  0:00:36s
# epoch 111| loss: 0.22535 | train_gini: 0.86636 | valid_gini: 0.58824 |  0:00:36s
# epoch 112| loss: 0.25276 | train_gini: 0.86099 | valid_gini: 0.60377 |  0:00:37s
# epoch 113| loss: 0.2248  | train_gini: 0.87442 | valid_gini: 0.6087  |  0:00:37s
# epoch 114| loss: 0.24591 | train_gini: 0.87037 | valid_gini: 0.68085 |  0:00:37s
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_valid_gini = 0.76923
#               precision    recall  f1-score   support
#
#          bad       0.68      0.81      0.74        31
#         good       0.94      0.88      0.91        99
#
#     accuracy                           0.86       130
#    macro avg       0.81      0.84      0.82       130
# weighted avg       0.87      0.86      0.87       130
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.87022 | train_gini: 0.34204 | valid_gini: 0.35514 |  0:00:00s
# epoch 1  | loss: 0.79693 | train_gini: 0.37584 | valid_gini: 0.22857 |  0:00:00s
# epoch 2  | loss: 0.70596 | train_gini: 0.25197 | valid_gini: 0.25806 |  0:00:00s
# epoch 3  | loss: 0.68548 | train_gini: 0.47748 | valid_gini: 0.59259 |  0:00:01s
# epoch 4  | loss: 0.67493 | train_gini: 0.60426 | valid_gini: 0.64    |  0:00:01s
# epoch 5  | loss: 0.65697 | train_gini: 0.55102 | valid_gini: 0.57778 |  0:00:01s
# epoch 6  | loss: 0.64541 | train_gini: 0.47436 | valid_gini: 0.4     |  0:00:02s
# epoch 7  | loss: 0.66852 | train_gini: 0.34848 | valid_gini: 0.375   |  0:00:02s
# epoch 8  | loss: 0.6269  | train_gini: 0.44304 | valid_gini: 0.375   |  0:00:02s
# epoch 9  | loss: 0.63482 | train_gini: 0.5614  | valid_gini: 0.51429 |  0:00:03s
# epoch 10 | loss: 0.64577 | train_gini: 0.53333 | valid_gini: 0.56    |  0:00:03s
# epoch 11 | loss: 0.60417 | train_gini: 0.53846 | valid_gini: 0.45714 |  0:00:03s
# epoch 12 | loss: 0.62859 | train_gini: 0.57416 | valid_gini: 0.56    |  0:00:04s
# epoch 13 | loss: 0.58524 | train_gini: 0.65116 | valid_gini: 0.6383  |  0:00:04s
# epoch 14 | loss: 0.55166 | train_gini: 0.60793 | valid_gini: 0.56    |  0:00:04s
# epoch 15 | loss: 0.5632  | train_gini: 0.59259 | valid_gini: 0.64    |  0:00:05s
# epoch 16 | loss: 0.51717 | train_gini: 0.61972 | valid_gini: 0.65217 |  0:00:05s
# epoch 17 | loss: 0.48845 | train_gini: 0.64912 | valid_gini: 0.65385 |  0:00:05s
# epoch 18 | loss: 0.52144 | train_gini: 0.60392 | valid_gini: 0.59649 |  0:00:06s
# epoch 19 | loss: 0.52854 | train_gini: 0.59124 | valid_gini: 0.6129  |  0:00:06s
# epoch 20 | loss: 0.50085 | train_gini: 0.62745 | valid_gini: 0.63158 |  0:00:06s
# epoch 21 | loss: 0.48865 | train_gini: 0.62651 | valid_gini: 0.62069 |  0:00:07s
# epoch 22 | loss: 0.51171 | train_gini: 0.62271 | valid_gini: 0.56667 |  0:00:07s
# epoch 23 | loss: 0.51318 | train_gini: 0.60759 | valid_gini: 0.61818 |  0:00:07s
# epoch 24 | loss: 0.46792 | train_gini: 0.6439  | valid_gini: 0.57143 |  0:00:08s
# epoch 25 | loss: 0.4296  | train_gini: 0.67593 | valid_gini: 0.54902 |  0:00:08s
# epoch 26 | loss: 0.46862 | train_gini: 0.63677 | valid_gini: 0.61538 |  0:00:08s
# epoch 27 | loss: 0.47382 | train_gini: 0.68246 | valid_gini: 0.57692 |  0:00:09s
# epoch 28 | loss: 0.50943 | train_gini: 0.66939 | valid_gini: 0.61538 |  0:00:09s
# epoch 29 | loss: 0.43492 | train_gini: 0.6729  | valid_gini: 0.62963 |  0:00:09s
# epoch 30 | loss: 0.42543 | train_gini: 0.71171 | valid_gini: 0.72    |  0:00:10s
# epoch 31 | loss: 0.38037 | train_gini: 0.69261 | valid_gini: 0.64286 |  0:00:10s
# epoch 32 | loss: 0.37052 | train_gini: 0.67692 | valid_gini: 0.63158 |  0:00:10s
# epoch 33 | loss: 0.40897 | train_gini: 0.71111 | valid_gini: 0.73077 |  0:00:11s
# epoch 34 | loss: 0.40734 | train_gini: 0.63063 | valid_gini: 0.7037  |  0:00:11s
# epoch 35 | loss: 0.42984 | train_gini: 0.65272 | valid_gini: 0.69091 |  0:00:11s
# epoch 36 | loss: 0.42155 | train_gini: 0.6692  | valid_gini: 0.62069 |  0:00:12s
# epoch 37 | loss: 0.40966 | train_gini: 0.672   | valid_gini: 0.65385 |  0:00:12s
# epoch 38 | loss: 0.42163 | train_gini: 0.66372 | valid_gini: 0.69388 |  0:00:12s
# epoch 39 | loss: 0.35812 | train_gini: 0.68    | valid_gini: 0.65385 |  0:00:13s
# epoch 40 | loss: 0.40045 | train_gini: 0.70042 | valid_gini: 0.7451  |  0:00:13s
# epoch 41 | loss: 0.38275 | train_gini: 0.7069  | valid_gini: 0.77551 |  0:00:13s
# epoch 42 | loss: 0.39965 | train_gini: 0.74043 | valid_gini: 0.79245 |  0:00:14s
# epoch 43 | loss: 0.39087 | train_gini: 0.73684 | valid_gini: 0.76    |  0:00:14s
# epoch 44 | loss: 0.32127 | train_gini: 0.71818 | valid_gini: 0.73469 |  0:00:14s
# epoch 45 | loss: 0.33825 | train_gini: 0.7395  | valid_gini: 0.7451  |  0:00:15s
# epoch 46 | loss: 0.36925 | train_gini: 0.74074 | valid_gini: 0.73077 |  0:00:15s
# epoch 47 | loss: 0.38652 | train_gini: 0.74897 | valid_gini: 0.71698 |  0:00:15s
# epoch 48 | loss: 0.35496 | train_gini: 0.75229 | valid_gini: 0.79167 |  0:00:16s
# epoch 49 | loss: 0.322   | train_gini: 0.79621 | valid_gini: 0.73913 |  0:00:16s
# epoch 50 | loss: 0.31241 | train_gini: 0.77885 | valid_gini: 0.73913 |  0:00:16s
# epoch 51 | loss: 0.33693 | train_gini: 0.80909 | valid_gini: 0.73469 |  0:00:17s
# epoch 52 | loss: 0.30773 | train_gini: 0.79787 | valid_gini: 0.71429 |  0:00:17s
# epoch 53 | loss: 0.32575 | train_gini: 0.79024 | valid_gini: 0.78261 |  0:00:17s
# epoch 54 | loss: 0.32989 | train_gini: 0.76364 | valid_gini: 0.80851 |  0:00:18s
# epoch 55 | loss: 0.29088 | train_gini: 0.78182 | valid_gini: 0.77551 |  0:00:18s
# epoch 56 | loss: 0.30059 | train_gini: 0.75983 | valid_gini: 0.78431 |  0:00:18s
# epoch 57 | loss: 0.304   | train_gini: 0.82028 | valid_gini: 0.7234  |  0:00:18s
# epoch 58 | loss: 0.29526 | train_gini: 0.81517 | valid_gini: 0.76596 |  0:00:19s
# epoch 59 | loss: 0.27564 | train_gini: 0.8018  | valid_gini: 0.79167 |  0:00:19s
# epoch 60 | loss: 0.25095 | train_gini: 0.75304 | valid_gini: 0.82353 |  0:00:19s
# epoch 61 | loss: 0.29174 | train_gini: 0.76987 | valid_gini: 0.82353 |  0:00:20s
# epoch 62 | loss: 0.29065 | train_gini: 0.80531 | valid_gini: 0.875   |  0:00:20s
# epoch 63 | loss: 0.24737 | train_gini: 0.80909 | valid_gini: 0.84444 |  0:00:21s
# epoch 64 | loss: 0.26819 | train_gini: 0.83178 | valid_gini: 0.82609 |  0:00:21s
# epoch 65 | loss: 0.29505 | train_gini: 0.83019 | valid_gini: 0.86364 |  0:00:22s
# epoch 66 | loss: 0.27847 | train_gini: 0.77447 | valid_gini: 0.82353 |  0:00:22s
# epoch 67 | loss: 0.27034 | train_gini: 0.79295 | valid_gini: 0.78431 |  0:00:23s
# epoch 68 | loss: 0.26951 | train_gini: 0.84112 | valid_gini: 0.8     |  0:00:23s
# epoch 69 | loss: 0.22501 | train_gini: 0.83036 | valid_gini: 0.8     |  0:00:23s
# epoch 70 | loss: 0.22221 | train_gini: 0.84305 | valid_gini: 0.82353 |  0:00:24s
# epoch 71 | loss: 0.27283 | train_gini: 0.76    | valid_gini: 0.79245 |  0:00:24s
# epoch 72 | loss: 0.29034 | train_gini: 0.79184 | valid_gini: 0.71429 |  0:00:24s
# epoch 73 | loss: 0.28868 | train_gini: 0.85581 | valid_gini: 0.7451  |  0:00:24s
# epoch 74 | loss: 0.2678  | train_gini: 0.86154 | valid_gini: 0.74419 |  0:00:25s
# epoch 75 | loss: 0.26029 | train_gini: 0.84507 | valid_gini: 0.73913 |  0:00:25s
# epoch 76 | loss: 0.26792 | train_gini: 0.78151 | valid_gini: 0.76596 |  0:00:25s
# epoch 77 | loss: 0.27182 | train_gini: 0.77291 | valid_gini: 0.76923 |  0:00:26s
# epoch 78 | loss: 0.28183 | train_gini: 0.78862 | valid_gini: 0.74074 |  0:00:26s
# epoch 79 | loss: 0.23721 | train_gini: 0.79012 | valid_gini: 0.83333 |  0:00:26s
# epoch 80 | loss: 0.27395 | train_gini: 0.78481 | valid_gini: 0.77551 |  0:00:27s
# epoch 81 | loss: 0.22468 | train_gini: 0.82791 | valid_gini: 0.7907  |  0:00:27s
# epoch 82 | loss: 0.23332 | train_gini: 0.84112 | valid_gini: 0.7907  |  0:00:27s
# epoch 83 | loss: 0.22654 | train_gini: 0.87324 | valid_gini: 0.7907  |  0:00:28s
# epoch 84 | loss: 0.19963 | train_gini: 0.8785  | valid_gini: 0.74419 |  0:00:28s
# epoch 85 | loss: 0.236   | train_gini: 0.85437 | valid_gini: 0.74419 |  0:00:28s
# epoch 86 | loss: 0.22094 | train_gini: 0.83178 | valid_gini: 0.65217 |  0:00:29s
# epoch 87 | loss: 0.23261 | train_gini: 0.82511 | valid_gini: 0.66667 |  0:00:29s
# epoch 88 | loss: 0.20858 | train_gini: 0.87037 | valid_gini: 0.69767 |  0:00:29s
# epoch 89 | loss: 0.20938 | train_gini: 0.84444 | valid_gini: 0.75    |  0:00:30s
# epoch 90 | loss: 0.28479 | train_gini: 0.84685 | valid_gini: 0.68085 |  0:00:30s
# epoch 91 | loss: 0.2195  | train_gini: 0.84906 | valid_gini: 0.69565 |  0:00:30s
# epoch 92 | loss: 0.21322 | train_gini: 0.84545 | valid_gini: 0.7234  |  0:00:30s
# epoch 93 | loss: 0.23465 | train_gini: 0.90323 | valid_gini: 0.7234  |  0:00:31s
# epoch 94 | loss: 0.22946 | train_gini: 0.89423 | valid_gini: 0.72727 |  0:00:31s
# epoch 95 | loss: 0.1794  | train_gini: 0.89202 | valid_gini: 0.78049 |  0:00:31s
# epoch 96 | loss: 0.18443 | train_gini: 0.85841 | valid_gini: 0.7907  |  0:00:32s
# epoch 97 | loss: 0.18292 | train_gini: 0.83621 | valid_gini: 0.75556 |  0:00:32s
# epoch 98 | loss: 0.1796  | train_gini: 0.87671 | valid_gini: 0.71429 |  0:00:32s
# epoch 99 | loss: 0.17635 | train_gini: 0.91346 | valid_gini: 0.78049 |  0:00:33s
# epoch 100| loss: 0.18145 | train_gini: 0.87558 | valid_gini: 0.7907  |  0:00:33s
# epoch 101| loss: 0.18308 | train_gini: 0.86239 | valid_gini: 0.78049 |  0:00:33s
# epoch 102| loss: 0.16855 | train_gini: 0.88038 | valid_gini: 0.75    |  0:00:34s
# epoch 103| loss: 0.19583 | train_gini: 0.89202 | valid_gini: 0.71429 |  0:00:34s
# epoch 104| loss: 0.15225 | train_gini: 0.93659 | valid_gini: 0.74419 |  0:00:34s
# epoch 105| loss: 0.1434  | train_gini: 0.88991 | valid_gini: 0.71429 |  0:00:35s
# epoch 106| loss: 0.17339 | train_gini: 0.90476 | valid_gini: 0.73171 |  0:00:35s
# epoch 107| loss: 0.13868 | train_gini: 0.90732 | valid_gini: 0.7619  |  0:00:35s
# epoch 108| loss: 0.13377 | train_gini: 0.9108  | valid_gini: 0.7619  |  0:00:35s
# epoch 109| loss: 0.11973 | train_gini: 0.9     | valid_gini: 0.7234  |  0:00:36s
# epoch 110| loss: 0.14149 | train_gini: 0.87225 | valid_gini: 0.69388 |  0:00:36s
# epoch 111| loss: 0.22219 | train_gini: 0.87671 | valid_gini: 0.7234  |  0:00:36s
# epoch 112| loss: 0.14596 | train_gini: 0.90233 | valid_gini: 0.71429 |  0:00:37s
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_valid_gini = 0.875
#               precision    recall  f1-score   support
#
#          bad       0.70      0.61      0.66        31
#         good       0.88      0.92      0.90        99
#
#     accuracy                           0.85       130
#    macro avg       0.79      0.77      0.78       130
# weighted avg       0.84      0.85      0.84       130
#
# Average Accuracy: 0.8621
# /Users/suvodeepmajumder/opt/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
conf_matrices

# %%
summary_df = pd.read_csv('../Results/Analysis_Results/Radiomics/summary/Tumor_summary.csv')
summary_df['property'] = summary_df['property'] + '_' +summary_df['Unnamed: 0'] + '_' +summary_df['analysis_type']

important_features = summary_df[(summary_df['Statistically_Different'] != '-') 
                                & (summary_df['Effect_Size'] != 'Small')].property.values.tolist()

important_features.append('WT dice')
important_features.append('TC dice')
important_features.append('ET dice')
results_df = results_df[important_features]
results_df.head()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# Load your dataset
# Assuming the DataFrame is named df and the outcome column is 'dice_score'
# df = pd.read_csv('path_to_your_dataset.csv')

# Separate features and target variable
X = results_df.drop(['WT dice', 'TC dice', 'ET dice'], axis=1)  # Features
y = results_df['WT dice']  # Target variable (Dice score)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the Gradient Boosting Regressor
model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
# model = linear_model.BayesianRidge()

# Train the model
model.fit(X_train_scaled, y_train)

# Predict on the testing set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2): {r2}")

# %%
X_test['WT dice'] = y_test
X_test['predicted WT dice'] = y_pred
X_test = X_test.round(2)

# %%
X_test[(X_test['WT dice'] < 0.9) & (X_test['predicted WT dice'] >= 0.9)]

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Assuming df is your DataFrame and the last column is the target variable
# Separate features and target variable
X = results_df.drop(['WT dice', 'TC dice', 'ET dice'], axis=1)  # Features
y = results_df['WT dice'].values.reshape(-1, 1)  # Target variable (Dice score)
# y = results_df.iloc[:, -1].values.reshape(-1, 1)  # Reshape for regression targets

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (important for neural networks)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# X_train = X_train.values
# X_test = X_test.values

# Custom dataset
class CustomDataset(Dataset):
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return torch.tensor(self.features[idx], dtype=torch.float), torch.tensor(self.targets[idx], dtype=torch.float)

# Create datasets and dataloaders
train_dataset = CustomDataset(X_train, y_train)
test_dataset = CustomDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import torch.nn as nn
import torch.nn.functional as F

class RegressionNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(RegressionNet, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, output_size)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class DeeperRegressionNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DeeperRegressionNet, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)  # First layer
        self.drop1 = nn.Dropout(0.1)  # Dropout layer
        self.fc2 = nn.Linear(256, 128)  # Second layer
        self.drop2 = nn.Dropout(0.1)  # Dropout layer
        self.fc3 = nn.Linear(128, 64)   # Third layer
        self.fc4 = nn.Linear(64, 32)    # Fourth layer
        self.fc5 = nn.Linear(32, output_size)  # Output layer
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.drop1(x)
        x = F.relu(self.fc2(x))
        x = self.drop2(x)
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
# model = RegressionNet(input_size=X_train.shape[1], output_size=1)
model = DeeperRegressionNet(input_size=X_train.shape[1], output_size=1)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 3000

for epoch in range(num_epochs):
    for inputs, targets in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# %%
model.eval()  # Set the model to evaluation mode
with torch.no_grad():  # Inference mode, gradients not calculated
    predictions = []
    actuals = []
    for inputs, targets in test_loader:
        outputs = model(inputs)
        predictions.extend(outputs.view(-1).tolist())
        actuals.extend(targets.view(-1).tolist())

# Calculate evaluation metrics such as R2 score or MSE here
mse = mean_squared_error(actuals, predictions)
r2 = r2_score(actuals, predictions)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2): {r2}")

# %%
X_test_copy = pd.DataFrame(X_test, columns = X.columns)
X_test_copy['WT dice'] = actuals
X_test_copy['predicted WT dice'] = predictions
X_test_copy = X_test_copy.round(2)

# %%
X_test_copy[(X_test_copy['WT dice'] < 0.87) & (X_test_copy['predicted WT dice'] >= 0.87)]

# %%
X_test_copy[(X_test_copy['WT dice'] >= 0.87) ]

# %%
x = [[0.455, 0.553],[0.634, 0.321], [0.634, 0.321]]
np.argmax(x, axis = 1)
